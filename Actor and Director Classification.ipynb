# %% [markdown]
# # Actor and Director Classification
# ### Ranking each actor and director based on two metrics: number of films and budget of those films

# %%
import pandas as pd
import ast

# %%
# import dataset 
df = pd.read_csv('tmdb_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                              title  year  \
# 0           0             Harry Potter and the Half-Blood Prince  2009
# 1           1                               Terminator Salvation  2009
# 2           2  Indiana Jones and the Kingdom of the Crystal S...  2008
# 3           3                                The Incredible Hulk  2008
# 4           6                                    The Dark Knight  2008
#
#     release_date                                               cast  \
# 0  July  8, 2009  ['Daniel Radcliffe', 'Rupert Grint', 'Emma Wat...
# 1   May 20, 2009  ['Christian Bale', 'Sam Worthington', 'Anton Y...
# 2   May 22, 2008  ['Harrison Ford', 'Cate Blanchett', 'Shia LaBe...
# 3  June 12, 2008  ['Edward Norton', 'Liv Tyler', 'Tim Roth', 'Wi...
# 4  July 14, 2008  ['Christian Bale', 'Michael Caine', 'Heath Led...
#
#                                                 crew rating  \
# 0  {'Director': ['David Yates'], 'Novel': ['J.K. ...     PG
# 1  {'Director': ['McG'], 'Writer': ['Michael Ferr...  PG-13
# 2  {'Characters': ['George Lucas', 'Philip Kaufma...  PG-13
# 3  {'Characters': ['Stan Lee', 'Jack Kirby'], 'Di...  PG-13
# 4  {'Director': ['Christopher Nolan'], 'Screenpla...  PG-13
#
#                                        genres  \
# 0          ['Adventure', 'Fantasy', 'Family']
# 1   ['Action', 'Science Fiction', 'Thriller']
# 2                     ['Adventure', 'Action']
# 3  ['Science Fiction', 'Action', 'Adventure']
# 4    ['Drama', 'Action', 'Crime', 'Thriller']
#
#                                             overview     budget  ...  studio  \
# 0  As Harry begins his sixth year at Hogwarts, he...  250000000  ...      WB
# 1  All grown up in post-apocalyptic 2018, John Co...  200000000  ...      WB
# 2  Set during the Cold War, the Soviets – led by ...  185000000  ...    Par.
# 3  Scientist Bruce Banner scours the planet for a...  150000000  ...    Uni.
# 4  Batman raises the stakes in his war on crime. ...  185000000  ...      WB
#
#     total_gross total_theaters openining_gross  opening_gross opening_date  \
# 0  $301,959,197           4455     $77,835,727           4325         7/15
# 1  $125,322,469           3602     $42,558,390           3530         5/21
# 2  $317,101,119           4264    $100,137,835           4260         5/22
# 3  $134,806,913           3508     $55,414,050           3505         6/13
# 4  $533,345,358           4366    $158,411,483           4366         7/18
#
#                                 production_companies runtime in_collection  \
# 0          ['Warner Bros. Pictures', 'Heyday Films']   153.0           1.0
# 1  ['Columbia Pictures', 'The Halcyon Company', '...   115.0           1.0
# 2                         ['Paramount', 'Lucasfilm']   122.0           1.0
# 3                                 ['Marvel Studios']   114.0           0.0
# 4  ['DC Comics', 'Legendary Entertainment', 'Sync...   152.0           1.0
#
#      imdb_id
# 0  tt0417741
# 1  tt0438488
# 2  tt0367882
# 3  tt0800080
# 4  tt0468569
#
# [5 rows x 22 columns]

# %% [markdown]
# #### First, create a dictionary for just the budget

# %%
actor_budget = {}
for i in range(len(df)):
    cast = df.iloc[i,4]
    # cast string into list
    cast_list = ast.literal_eval(cast)
    # adding to new dictionary
    for actor in cast_list:
        if actor_budget.get(actor) == None:
            actor_budget[actor] = float(df.iloc[i, 10])
        else:
            actor_budget[actor] += float(df.iloc[i, 10])

# %% [markdown]
# #### Next, create a dictionary for the number of films each actor is in

# %%
actor_freq = {}
for i in range(len(df)):
    cast = df.iloc[i,4]
    # cast string into list
    cast_list = ast.literal_eval(cast)
    for actor in cast_list:
        if actor_freq.get(actor) == None:
            actor_freq[actor] = 1
        else:
            actor_freq[actor] += 1

# %% [markdown]
# #### Lastly, compile both results into one dictionary and sort

# %%
actor_score = {}
actor_list = actor_budget.keys()
for actor in actor_list:
    if actor_score.get(actor) == None:
            actor_score[actor] = actor_freq.get(actor) * actor_budget.get(actor)
    else:
        actor_score[actor] += 1
#sort dictionary in DESCENDING order
sorted_actors = sorted(actor_score.items(), key=lambda x: x[1], reverse=True)

# %%
sorted_actors
# Out:
# [('Robert Downey Jr.', 169139593826.0),
#  ('Dwayne Johnson', 161013873182.0),
#  ('Scarlett Johansson', 117302316480.0),
#  ('Chris Hemsworth', 109135204368.0),
#  ('Mark Wahlberg', 85456451020.0),
#  ('Bradley Cooper', 84138040058.0),
#  ('Chris Evans', 68591147848.0),
#  ('Jennifer Lawrence', 66855489972.0),
#  ('Woody Harrelson', 64581646454.0),
#  ('Mark Ruffalo', 63513375360.0),
#  ('Samuel L. Jackson', 62057192223.0),
#  ('Vin Diesel', 48337524280.0),
#  ('Simon Pegg', 47968524750.0),
#  ('Emma Stone', 47656149646.0),
#  ('Ryan Reynolds', 46632812472.0),
#  ('Chris Pratt', 45675195507.0),
#  ('Steve Carell', 44954567568.0),
#  ('Johnny Depp', 44578158944.0),
#  ('Tom Cruise', 41651902457.0),
#  ('Kevin Hart', 40057676282.0),
#  ('Gary Oldman', 37270846647.0),
#  ('Christian Bale', 35172078290.0),
#  ('Jason Bateman', 35152790148.0),
#  ('John Goodman', 34953003862.0),
#  ('Harrison Ford', 34560900396.0),
#  ('Owen Wilson', 34424744705.0),
#  ('Chris Pine', 33970068011.0),
#  ('Cate Blanchett', 33568533297.0),
#  ('Tom Hanks', 33448931153.0),
#  ('Matt Damon', 32984828383.0),
#  ('Zoe Saldana', 31781116098.0),
#  ('Kristen Wiig', 31124011203.0),
#  ('Ben Stiller', 30773761210.0),
#  ('Elizabeth Banks', 30376917963.0),
#  ('Jonah Hill', 30078941472.0),
#  ('Adam Sandler', 30011839392.0),
#  ('Michael Fassbender', 29455208793.0),
#  ('Amy Adams', 29144872550.0),
#  ('Anne Hathaway', 28674031368.0),
#  ('Angelina Jolie', 28163985248.0),
#  ('Jason Statham', 27988300863.0),
#  ('Christoph Waltz', 27469561527.0),
#  ('Jack Black', 27413628728.0),
#  ('Gerard Butler', 27408023665.0),
#  ('Liam Neeson', 27314552759.0),
#  ('Hugh Jackman', 25879411584.0),
#  ('Jessica Chastain', 25869266126.0),
#  ('Josh Hutcherson', 25689888616.0),
#  ('Anna Kendrick', 24322248886.0),
#  ('George Clooney', 23922969732.0),
#  ('Rachel McAdams', 23326258637.0),
#  ('Michelle Rodriguez', 23274283302.0),
#  ('Emily Blunt', 22829239587.0),
#  ('Sam Worthington', 22645087290.0),
#  ('Daniel Craig', 22551882983.0),
#  ('Meryl Streep', 22289211348.0),
#  ('Kevin James', 22216859150.0),
#  ('John Leguizamo', 22139502088.0),
#  ('Idris Elba', 21879577880.0),
#  ('Bryce Dallas Howard', 21691100016.0),
#  ('Ben Affleck', 21656550368.0),
#  ('Martin Freeman', 21641758750.0),
#  ('Bill Hader', 21601284075.0),
#  ('Jesse Eisenberg', 21428351320.0),
#  ('Tyrese Gibson', 21406057720.0),
#  ('James McAvoy', 20631466000.0),
#  ('Charlize Theron', 20353500189.0),
#  ('Michael Keaton', 20169582642.0),
#  ('Jon Favreau', 20062458304.0),
#  ('Brad Pitt', 19391142744.0),
#  ('Amanda Seyfried', 19375331040.0),
#  ('Sandra Bullock', 19276142270.0),
#  ('T.J. Miller', 19092976560.0),
#  ('Mila Kunis', 19073998800.0),
#  ('Jeremy Renner', 19058406704.0),
#  ('Ralph Fiennes', 18980027017.0),
#  ('Zac Efron', 18936854200.0),
#  ('Leonardo DiCaprio', 18679797654.0),
#  ('Michael Caine', 18400813580.0),
#  ('Tom Hardy', 18197591058.0),
#  ('Rose Byrne', 18045858760.0),
#  ('Will Ferrell', 17631368656.0),
#  ('Matthew McConaughey', 17422093386.0),
#  ('Mark Strong', 17370200328.0),
#  ('Zach Galifianakis', 17096045400.0),
#  ('Evangeline Lilly', 16778372000.0),
#  ('Robert De Niro', 16769951715.0),
#  ('Liam Hemsworth', 16669222845.0),
#  ('Josh Duhamel', 16601731728.0),
#  ('Tom Hiddleston', 16600755954.0),
#  ('Andy Samberg', 16379901027.0),
#  ('Jude Law', 16368338903.0),
#  ('Henry Cavill', 16085757380.0),
#  ('Jason Sudeikis', 15955367230.0),
#  ('Jake Gyllenhaal', 15756150000.0),
#  ('Patrick Wilson', 15625937782.0),
#  ('Jamie Foxx', 15447827850.0),
#  ('Vera Farmiga', 15083258760.0),
#  ('Seth Rogen', 14686242204.0),
#  ('Shia LaBeouf', 14675524290.0),
#  ('Jason Segel', 14644139265.0),
#  ('Ken Jeong', 14547311730.0),
#  ('Benedict Cumberbatch', 13998470754.0),
#  ('Adam Driver', 13991293484.0),
#  ('Kristen Bell', 13911887906.0),
#  ('Helen Mirren', 13849607600.0),
#  ('Paul Rudd', 13782148656.0),
#  ('Channing Tatum', 13765904982.0),
#  ('Josh Gad', 13640651388.0),
#  ('Michael Peña', 13365693523.0),
#  ('Morgan Freeman', 12980077587.0),
#  ('Ian McShane', 12755544132.0),
#  ('Frances McDormand', 12624207420.0),
#  ('Leslie Mann', 12416625400.0),
#  ('Jeff Bridges', 12245655896.0),
#  ('Bruce Willis', 12235036720.0),
#  ('Jenny Slate', 12187167815.0),
#  ('Josh Brolin', 12094960024.0),
#  ('Denzel Washington', 12021283791.0),
#  ('Jackie Chan', 11962295874.0),
#  ('Paul Walker', 11960490320.0),
#  ('John C. Reilly', 11932818000.0),
#  ('John Malkovich', 11736486948.0),
#  ('Denis Leary', 11698905976.0),
#  ('Cameron Diaz', 11676699937.0),
#  ('Sebastian Stan', 11669527330.0),
#  ('Ed Helms', 11572217816.0),
#  ('Will Smith', 11571651816.0),
#  ('Gal Gadot', 11529010620.0),
#  ('Guy Pearce', 11496863535.0),
#  ('Joseph Gordon-Levitt', 11218506208.0),
#  ('Sylvester Stallone', 11100237328.0),
#  ('Dustin Hoffman', 11080791255.0),
#  ('Judi Dench', 10886227985.0),
#  ('Anthony Hopkins', 10790041415.0),
#  ('Don Cheadle', 10708729490.0),
#  ('Seann William Scott', 10642343400.0),
#  ('Reese Witherspoon', 10618827672.0),
#  ('Ryan Gosling', 10603211168.0),
#  ('Stanley Tucci', 10587919710.0),
#  ('Richard Jenkins', 10300819696.0),
#  ('Queen Latifah', 10265163210.0),
#  ('Gwyneth Paltrow', 10248396564.0),
#  ('Anthony Mackie', 10113350112.0),
#  ('Chiwetel Ejiofor', 10076541670.0),
#  ('Natalie Portman', 9935228730.0),
#  ('Russell Crowe', 9631230246.0),
#  ('Margot Robbie', 9497747695.0),
#  ('Justin Timberlake', 9490598845.0),
#  ('Jay Baruchel', 9432960760.0),
#  ('Michael B. Jordan', 9261388465.0),
#  ('Stephen Lang', 9208628106.0),
#  ('Catherine Keener', 9065434476.0),
#  ('Aaron Eckhart', 9061376600.0),
#  ('Sigourney Weaver', 9008880081.0),
#  ('Ray Romano', 8915256932.0),
#  ('Jennifer Aniston', 8906191864.0),
#  ('Ian McKellen', 8806570068.0),
#  ('Richard Armitage', 8806570068.0),
#  ('Kristen Stewart', 8794142388.0),
#  ('Jon Hamm', 8255549060.0),
#  ('Andy Serkis', 8215914192.0),
#  ('Hailee Steinfeld', 8211226980.0),
#  ('Brendan Gleeson', 8132718852.0),
#  ('Steve Buscemi', 8033677256.0),
#  ('Russell Brand', 7973721324.0),
#  ('J.K. Simmons', 7962310248.0),
#  ('Rebecca Ferguson', 7820380884.0),
#  ('Sharlto Copley', 7685692200.0),
#  ('Domhnall Gleeson', 7680703698.0),
#  ('Alec Baldwin', 7675199616.0),
#  ("Vincent D'Onofrio", 7664903700.0),
#  ('Robert Pattinson', 7664367308.0),
#  ('Dakota Johnson', 7646613835.0),
#  ('Danny McBride', 7616349664.0),
#  ('Nick Robinson', 7505875184.0),
#  ('Irrfan Khan', 7502253096.0),
#  ('Chris Rock', 7476944380.0),
#  ('Andrew Garfield', 7432623832.0),
#  ('Justin Long', 7202147550.0),
#  ('Joan Cusack', 7163280672.0),
#  ('Chloë Grace Moretz', 7146018168.0),
#  ('Viola Davis', 7107584712.0),
#  ('Kevin Costner', 7049810988.0),
#  ('Craig T. Nelson', 6999192932.0),
#  ('Anna Faris', 6958137186.0),
#  ('Kaya Scodelario', 6954522068.0),
#  ('Paula Patton', 6852390115.0),
#  ('Mark Hamill', 6801366322.0),
#  ('Carrie Fisher', 6801366322.0),
#  ('Daisy Ridley', 6801366322.0),
#  ('Lake Bell', 6786440455.0),
#  ('Geoffrey Rush', 6762352017.0),
#  ('Eric Bana', 6718047385.0),
#  ('Taraji P. Henson', 6699013515.0),
#  ('America Ferrera', 6663524396.0),
#  ('Nicholas Hoult', 6597930985.0),
#  ('Colin Firth', 6587633072.0),
#  ('Sam Rockwell', 6581834480.0),
#  ('Bryan Cranston', 6416448678.0),
#  ('Allison Janney', 6336432484.0),
#  ('Javier Bardem', 6322041051.0),
#  ('Vince Vaughn', 6243848472.0),
#  ('Naomie Harris', 6149093907.0),
#  ('Bobby Cannavale', 6144923308.0),
#  ('Kyle Chandler', 6067849685.0),
#  ('Hank Azaria', 6032973576.0),
#  ('Seth MacFarlane', 5940978488.0),
#  ('Elle Fanning', 5843294500.0),
#  ('Nicole Kidman', 5779637032.0),
#  ("Dylan O'Brien", 5661984265.0),
#  ('Ben Kingsley', 5516821505.0),
#  ('Neil Patrick Harris', 5467695456.0),
#  ('Toby Kebbell', 5428828164.0),
#  ('Taylor Lautner', 5405806791.0),
#  ("Lupita Nyong'o", 5365210701.0),
#  ('Casey Affleck', 5311580470.0),
#  ('Jennifer Connelly', 5301450920.0),
#  ('Rebel Wilson', 5246744545.0),
#  ('Thomas Haden Church', 5180387322.0),
#  ('Eddie Marsan', 5159285048.0),
#  ('Dev Patel', 5135521045.0),
#  ('Maya Rudolph', 5126149845.0),
#  ('Robin Wright', 5116308320.0),
#  ('Zachary Quinto', 5113939832.0),
#  ('Will Arnett', 5099283270.0),
#  ('Will Poulter', 5038859500.0),
#  ('Julia Roberts', 5024664862.0),
#  ('Billy Burke', 4981064024.0),
#  ('Dave Bautista', 4979651139.0),
#  ('Marisa Tomei', 4912813004.0),
#  ('Walton Goggins', 4911629536.0),
#  ('Carla Gugino', 4896878890.0),
#  ('Craig Ferguson', 4864586046.0),
#  ('Tessa Thompson', 4834239796.0),
#  ('Diane Keaton', 4834013096.0),
#  ('Melissa McCarthy', 4813825992.0),
#  ('James Franco', 4808499505.0),
#  ('Ving Rhames', 4787377089.0),
#  ('Katherine Heigl', 4760632878.0),
#  ('John Turturro', 4718586632.0),
#  ('David Cross', 4680316420.0),
#  ('Rebecca Hall', 4658435157.0),
#  ('Halle Berry', 4653734372.0),
#  ('Nick Nolte', 4646644974.0),
#  ('Michelle Monaghan', 4642959948.0),
#  ('Ed Harris', 4642881184.0),
#  ('John Krasinski', 4570995348.0),
#  ('Michelle Williams', 4557102025.0),
#  ('Willem Dafoe', 4549769862.0),
#  ('Amy Poehler', 4545822704.0),
#  ('James Corden', 4511772388.0),
#  ('Rami Malek', 4340188383.0),
#  ('Stellan Skarsgård', 4247345082.0),
#  ('Julie Andrews', 4225732080.0),
#  ('Brenton Thwaites', 4223534216.0),
#  ('Luke Evans', 4200144255.0),
#  ('Felicity Jones', 4199415660.0),
#  ('Zachary Levi', 4195404636.0),
#  ('Helena Bonham Carter', 4193942528.0),
#  ('Diego Luna', 4190353671.0),
#  ('Daniel Radcliffe', 4189773810.0),
#  ('Penélope Cruz', 4183501929.0),
#  ('Giovanni Ribisi', 4174382092.0),
#  ('Emma Watson', 4150490010.0),
#  ('Karl Urban', 4142883500.0),
#  ('Tommy Lee Jones', 4085201772.0),
#  ('Rainn Wilson', 4048322544.0),
#  ('Tom Holland', 4023234174.0),
#  ('Steve Coogan', 4021868034.0),
#  ('Robin Williams', 4020624912.0),
#  ('Teresa Palmer', 4004642115.0),
#  ('Miranda Cosgrove', 4004628940.0),
#  ('Dana Gaier', 4004628940.0),
#  ('Jamie Dornan', 3954424146.0),
#  ('Blake Lively', 3939217056.0),
#  ('Joel Edgerton', 3938759990.0),
#  ('Pierce Brosnan', 3907440532.0),
#  ('Amber Heard', 3896036196.0),
#  ('Jason Clarke', 3876413004.0),
#  ('Danny Huston', 3809433645.0),
#  ('Nicolas Cage', 3786606292.0),
#  ('Amy Ryan', 3742584115.0),
#  ('Mary Steenburgen', 3719428330.0),
#  ('Ben Foster', 3678805850.0),
#  ('Kathryn Hahn', 3658047950.0),
#  ('Demián Bichir', 3649458636.0),
#  ('Djimon Hounsou', 3647666788.0),
#  ('Tina Fey', 3616887185.0),
#  ('Emily Mortimer', 3610391043.0),
#  ('Jason Momoa', 3603226976.0),
#  ('Nick Frost', 3596195535.0),
#  ('Jack McBrayer', 3592882767.0),
#  ('Dominic Cooper', 3566396292.0),
#  ('Colin Farrell', 3559214340.0),
#  ('Jack Reynor', 3550959717.0),
#  ('Amanda Peet', 3543003987.0),
#  ('Benjamin Bratt', 3542575800.0),
#  ('Megan Fox', 3509939586.0),
#  ('Edward Norton', 3495896465.0),
#  ('Octavia Spencer', 3416142105.0),
#  ('Jennifer Garner', 3415255921.0),
#  ('Ellie Kemper', 3370072048.0),
#  ('Billy Crudup', 3345351448.0),
#  ('Sacha Baron Cohen', 3336212901.0),
#  ('Christina Applegate', 3288068875.0),
#  ('Jayma Mays', 3283429896.0),
#  ('Freida Pinto', 3263024238.0),
#  ('Jamie Bell', 3253216288.0),
#  ('Justin Bartha', 3227180031.0),
#  ('Liev Schreiber', 3223574516.0),
#  ('Dave Franco', 3221123580.0),
#  ('Taylor Kitsch', 3210512548.0),
#  ('Zooey Deschanel', 3187927892.0),
#  ('Tim Allen', 3173545100.0),
#  ('Ray Winstone', 3141922596.0),
#  ('Zendaya', 3128589680.0),
#  ('Susan Sarandon', 3117276246.0),
#  ('Isla Fisher', 3114791640.0),
#  ('Vanessa Hudgens', 3082706664.0),
#  ('Joel Kinnaman', 3075713709.0),
#  ('Regina Hall', 3072156703.0),
#  ('Alan Tudyk', 3054560324.0),
#  ('Laurence Fishburne', 3034013016.0),
#  ('Jane Lynch', 3032033850.0),
#  ('Cedric the Entertainer', 2975412788.0),
#  ('Rosamund Pike', 2959739376.0),
#  ('Salma Hayek', 2935675368.0),
#  ('Campbell Scott', 2915866578.0),
#  ('Jemaine Clement', 2895193671.0),
#  ('Chadwick Boseman', 2883518640.0),
#  ('Eddie Redmayne', 2883210936.0),
#  ('Kate McKinnon', 2881253720.0),
#  ('Katie Featherston', 2877558568.0),
#  ('Sofía Vergara', 2864867040.0),
#  ('Marion Cotillard', 2847496372.0),
#  ('Jordana Brewster', 2829635050.0),
#  ('Nicola Peltz', 2819816040.0),
#  ('Ice Cube', 2816919085.0),
#  ('Ashley Greene', 2816637618.0),
#  ('Selena Gomez', 2795335683.0),
#  ('Michael Shannon', 2790499317.0),
#  ('Ewan McGregor', 2788877348.0),
#  ('Mary Elizabeth Winstead', 2788387540.0),
#  ('Joel David Moore', 2787965087.0),
#  ('Jada Pinkett Smith', 2784639147.0),
#  ('Danai Gurira', 2783322818.0),
#  ('Dennis Quaid', 2781467284.0),
#  ('Justice Smith', 2777943770.0),
#  ('Jon Bernthal', 2769843350.0),
#  ('Olivia Wilde', 2753359930.0),
#  ('Simon McBurney', 2706787268.0),
#  ('Ben Mendelsohn', 2702766000.0),
#  ('David Schwimmer', 2701643256.0),
#  ('Ned Beatty', 2625388612.0),
#  ('Antonio Banderas', 2615176688.0),
#  ('Holly Hunter', 2596390104.0),
#  ('Jeff Daniels', 2594284872.0),
#  ('Jim Carrey', 2575558968.0),
#  ('John Cena', 2563824957.0),
#  ('Kelsey Grammer', 2547568750.0),
#  ('Alexandra Daddario', 2544593694.0),
#  ('Jet Li', 2524826058.0),
#  ('Christopher Plummer', 2521570347.0),
#  ('Lily James', 2519324476.0),
#  ('Bill Nighy', 2493329480.0),
#  ('Abigail Breslin', 2461461630.0),
#  ('Abbie Cornish', 2453262028.0),
#  ('Peter Dinklage', 2448637592.0),
#  ('Ken Watanabe', 2422865804.0),
#  ('Alfred Molina', 2388488964.0),
#  ('Ed Skrein', 2375905086.0),
#  ('Sarah Jessica Parker', 2366642184.0),
#  ('Michael Douglas', 2365387308.0),
#  ('Luis Guzmán', 2365288704.0),
#  ('Bill Paxton', 2364357176.0),
#  ('Julianne Moore', 2329690377.0),
#  ('Armie Hammer', 2327339108.0),
#  ('Michael Ealy', 2318742470.0),
#  ('Julie Walters', 2304854619.0),
#  ('Wendi McLendon-Covey', 2296592912.0),
#  ('Emma Roberts', 2277497996.0),
#  ('Kevin Bacon', 2258634592.0),
#  ('Angela Bassett', 2245861016.0),
#  ('Brie Larson', 2239859205.0),
#  ('Ashton Kutcher', 2231940164.0),
#  ('Linda Cardellini', 2229297951.0),
#  ('Melissa Leo', 2219378596.0),
#  ('Alan Arkin', 2201375012.0),
#  ('Paul Giamatti', 2197019900.0),
#  ('Peter Facinelli', 2184216270.0),
#  ('Alicia Vikander', 2181015393.0),
#  ('Alexander Skarsgård', 2180247006.0),
#  ('Ginnifer Goodwin', 2177750032.0),
#  ('Bruce Greenwood', 2165868837.0),
#  ('Jessica Alba', 2157533465.0),
#  ('Phyllis Smith', 2147617332.0),
#  ('Jack Dylan Grazer', 2127830038.0),
#  ('Terrence Howard', 2121494382.0),
#  ('Jaden Smith', 2100412428.0),
#  ('David Harbour', 2085823880.0),
#  ('Britt Robertson', 2071916128.0),
#  ('James Badge Dale', 2071698840.0),
#  ('Aaron Paul', 2064846021.0),
#  ('Emma Thompson', 2062556622.0),
#  ('Eric Stonestreet', 2061220974.0),
#  ('Li Bingbing', 2052077859.0),
#  ('Suraj Sharma', 2017955076.0),
#  ('Maria Bello', 2016372483.0),
#  ('Karen Gillan', 2012300220.0),
#  ('Joel McHale', 2011072353.0),
#  ('Sarah Silverman', 2000888086.0),
#  ('James Marsden', 1970492076.0),
#  ('Tom Felton', 1960057530.0),
#  ('Louis C.K.', 1949328304.0),
#  ('Eloise Mumford', 1899667244.0),
#  ('Kevin Spacey', 1892672004.0),
#  ('Larry the Cable Guy', 1887555344.0),
#  ('Charlie Hunnam', 1885373382.0),
#  ('William Hurt', 1876629315.0),
#  ('Brendan Fraser', 1876081995.0),
#  ('Chris Cooper', 1869895350.0),
#  ('Jae Head', 1866475360.0),
#  ('Dane DeHaan', 1863183320.0),
#  ('David Spade', 1855771401.0),
#  ('Terence Stamp', 1850474520.0),
#  ('Keri Russell', 1847038016.0),
#  ('Tracy Morgan', 1837020580.0),
#  ('Asa Butterfield', 1823379210.0),
#  ('Eddie Murphy', 1811062980.0),
#  ('Kelly Reilly', 1793161011.0),
#  ('Katherine Waterston', 1771472288.0),
#  ('Gael García Bernal', 1765349106.0),
#  ('Milla Jovovich', 1764289596.0),
#  ('Lily Collins', 1762870212.0),
#  ('Brittany Snow', 1762743342.0),
#  ('Nikolaj Coster-Waldau', 1750041621.0),
#  ('Ethan Hawke', 1749057176.0),
#  ('Connie Nielsen', 1748890022.0),
#  ('Olga Kurylenko', 1744518598.0),
#  ('Billy Crystal', 1726663678.0),
#  ('Max Martini', 1716042828.0),
#  ('Michael Cera', 1714928665.0),
#  ('Sienna Miller', 1689552880.0),
#  ('Keanu Reeves', 1689367728.0),
#  ('Tobin Bell', 1684777936.0),
#  ('Adam Scott', 1679572332.0),
#  ('Ben Barnes', 1670703570.0),
#  ('Georgie Henley', 1670703570.0),
#  ('Skandar Keynes', 1670703570.0),
#  ('John Cusack', 1668451714.0),
#  ('Oliver Platt', 1664022990.0),
#  ('John Travolta', 1657096290.0),
#  ('Kevin Kline', 1641632872.0),
#  ('Lizzy Caplan', 1629009228.0),
#  ('Brad Garrett', 1623167296.0),
#  ('Lesley Manville', 1612592750.0),
#  ('Rhys Ifans', 1612251216.0),
#  ('Jared Leto', 1601596678.0),
#  ('Mike Myers', 1588839862.0),
#  ('Jeremy Ray Taylor', 1585770720.0),
#  ('Famke Janssen', 1583163958.0),
#  ('Jason Lee', 1571670880.0),
#  ('Michael Nyqvist', 1566950082.0),
#  ('Marlon Wayans', 1563854640.0),
#  ('Tom Wilkinson', 1563387712.0),
#  ('Patrick Dempsey', 1539119265.0),
#  ('Tyler Perry', 1531272324.0),
#  ('Alice Braga', 1525311438.0),
#  ('Mathieu Amalric', 1521382090.0),
#  ('Rosario Dawson', 1517477748.0),
#  ('Jaeden Martell', 1510437964.0),
#  ('Robert Redford', 1501515318.0),
#  ('Jamie Chung', 1495222228.0),
#  ('Jeff Goldblum', 1494893166.0),
#  ('Eric Johnson', 1494270508.0),
#  ('Luke Grimes', 1488898132.0),
#  ('Vincent Cassel', 1486577290.0),
#  ('Noomi Rapace', 1475570284.0),
#  ('Benedict Wong', 1474504744.0),
#  ('Alex Pettyfer', 1456934991.0),
#  ('Mahershala Ali', 1449105086.0),
#  ('Leslie Bibb', 1423729896.0),
#  ('Ludacris', 1423109160.0),
#  ('Kim Cattrall', 1407200956.0),
#  ('Cynthia Nixon', 1407200956.0),
#  ('Kristin Davis', 1407200956.0),
#  ('Chris Noth', 1407200956.0),
#  ('Ike Barinholtz', 1400529717.0),
#  ('Mel Gibson', 1385061189.0),
#  ('Rosa Salazar', 1379468292.0),
#  ('Olivia Cooke', 1372960886.0),
#  ('Julianne Hough', 1362422216.0),
#  ('Kate Hudson', 1357613932.0),
#  ('Rachel Weisz', 1356669987.0),
#  ('Drew Barrymore', 1350106971.0),
#  ('Forest Whitaker', 1338778512.0),
#  ('John Boyega', 1332459537.0),
#  ('Christopher Mintz-Plasse', 1332126696.0),
#  ('John Lithgow', 1326946730.0),
#  ('Lynn Collins', 1314403928.0),
#  ('Rafe Spall', 1303459585.0),
#  ('Daniella Pineda', 1303459585.0),
#  ('Aldis Hodge', 1300642650.0),
#  ('Andy García', 1298940082.0),
#  ('Keira Knightley', 1285768152.0),
#  ('Mia Wasikowska', 1283440278.0),
#  ('Anthony Anderson', 1282636701.0),
#  ('Idina Menzel', 1274219009.0),
#  ('Jonathan Groff', 1274219009.0),
#  ('Santino Fontana', 1274219009.0),
#  ('Mandy Moore', 1272059918.0),
#  ('Cliff Curtis', 1268986488.0),
#  ('Ki Hong Lee', 1266363206.0),
#  ('Dylan Minnette', 1253593758.0),
#  ('Sarah Vowell', 1241891456.0),
#  ('Eli Fucile', 1241891456.0),
#  ('Huck Milner', 1241891456.0),
#  ('Corey Stoll', 1239716236.0),
#  ('Kyle Gallner', 1239670310.0),
#  ('Mireille Enos', 1221479686.0),
#  ('Olivia Munn', 1219650558.0),
#  ('Bill Murray', 1217337820.0),
#  ('Sam Claflin', 1209090150.0),
#  ('Emilia Clarke', 1201794896.0),
#  ('Thomas Brodie-Sangster', 1192277058.0),
#  ('Saoirse Ronan', 1184968312.0),
#  ('Sterling Jerins', 1172567744.0),
#  ('Jim Broadbent', 1166955780.0),
#  ('Oscar Isaac', 1161608402.0),
#  ('Doug Jones', 1146134745.0),
#  ('Hiroyuki Sanada', 1132806296.0),
#  ('Jennifer Lopez', 1127540360.0),
#  ('Logan Lerman', 1124975576.0),
#  ('Ashley Judd', 1111741180.0),
#  ('Sam Neill', 1094762006.0),
#  ('Clive Owen', 1090719756.0),
#  ('Steve Zahn', 1087464022.0),
#  ('Matthew Broderick', 1078169199.0),
#  ('Charlie Day', 1075072122.0),
#  ('Paul Dano', 1068506061.0),
#  ('Rihanna', 1057799426.0),
#  ('Bruce McGill', 1056750567.0),
#  ('Donnie Yen', 1056057273.0),
#  ('Jiang Wen', 1056057273.0),
#  ('Kevin McNally', 1045713802.0),
#  ('Juliette Lewis', 1040558781.0),
#  ('Arnold Schwarzenegger', 1037491934.0),
#  ('Trey Parker', 1031552585.0),
#  ('Ellen DeGeneres', 1028570889.0),
#  ('Albert Brooks', 1028570889.0),
#  ('Hayden Rolence', 1028570889.0),
#  ("Ed O'Neill", 1028570889.0),
#  ('Rosemarie DeWitt', 1027407124.0),
#  ('Nate Torrence', 1023784195.0),
#  ('James Nesbitt', 1021103568.0),
#  ('Ken Stott', 1021103568.0),
#  ('Rooney Mara', 1015892379.0),
#  ('Radha Mitchell', 1015279656.0),
#  ('Matthew Gray Gubler', 1007725478.0),
#  ('David Oyelowo', 1006481640.0),
#  ('Heath Ledger', 1004558444.0),
#  ('Maika Monroe', 999176614.0),
#  ('Tilda Swinton', 995304304.0),
#  ('Douglas Smith', 990323349.0),
#  ('Bill Pullman', 983532594.0),
#  ('Meagan Good', 983126436.0),
#  ('James Caan', 982746174.0),
#  ('Colm Meaney', 980161146.0),
#  ("O'Shea Jackson Jr.", 973113444.0),
#  ('Laura Linney', 968187762.0),
#  ('Nick Jonas', 962119864.0),
#  ('Costas Mandylor', 954724788.0),
#  ('Betsy Russell', 954724788.0),
#  ('Sebastian Koch', 940265060.0),
#  ('Rupert Grint', 933959197.0),
#  ('Michael Gambon', 933959197.0),
#  ('Cobie Smulders', 932712966.0),
#  ('Morris Chestnut', 924516532.0),
#  ('Tika Sumpter', 923933259.0),
#  ('Frank Grillo', 923383728.0),
#  ('Rob Corddry', 922867299.0),
#  ('Donald Glover', 914126202.0),
#  ('Alden Ehrenreich', 913200058.0),
#  ('Scoot McNairy', 910267456.0),
#  ('Jared Harris', 908270046.0),
#  ('Tadanobu Asano', 907975920.0),
#  ('Nick Swardson', 906856293.0),
#  ('Kerry Washington', 906016532.0),
#  ('Gwilym Lee', 894027543.0),
#  ('Ben Hardy', 894027543.0),
#  ('Joseph Mazzello', 894027543.0),
#  ('Lucy Boynton', 894027543.0),
#  ('Emile Hirsch', 893483853.0),
#  ('David Koechner', 886737273.0),
#  ('Ben Whishaw', 885255696.0),
#  ('Robert Duvall', 884575953.0),
#  ('Clint Eastwood', 882525270.0),
#  ('Léa Seydoux', 880674609.0),
#  ('Josh Peck', 877244782.0),
#  ('Mélanie Laurent', 873659888.0),
#  ('Rade Šerbedžija', 864902144.0),
#  ('Jackie Earle Haley', 861572264.0),
#  ('Richard Kind', 857611174.0),
#  ('Lewis Black', 857611174.0),
#  ('Charles Dance', 850138710.0),
#  ('Kristin Scott Thomas', 844438426.0),
#  ('Ron Livingston', 841448860.0),
#  ('Miles Teller', 840783603.0),
#  ('Matthew Goode', 837629382.0),
#  ('Ryan Lee', 836517550.0),
#  ('Alison Brie', 834194151.0),
#  ('Ellen Page', 825532764.0),
#  ('Dolph Lundgren', 824829442.0),
#  ('Miley Cyrus', 816843896.0),
#  ('Ramón Rodríguez', 811488784.0),
#  ('Michael Sheen', 808479012.0),
#  ('Ciarán Hinds', 808244211.0),
#  ('Skylar Astin', 805713240.0),
#  ('Edgar Ramírez', 804268118.0),
#  ('Tim McGraw', 804265428.0),
#  ('Anthony Gonzalez', 800526015.0),
#  ('Alanna Ubach', 800526015.0),
#  ('Renée Victor', 800526015.0),
#  ('Keith David', 791187552.0),
#  ('Winona Ryder', 789832790.0),
#  ('Kate Winslet', 789802560.0),
#  ('Karen Allen', 786636033.0),
#  ('Morena Baccarin', 783100000.0),
#  ('Gina Carano', 783100000.0),
#  ('Greg Kinnear', 780147900.0),
#  ('Katie Holmes', 779241498.0),
#  ('Neve Campbell', 778979922.0),
#  ('Jeremy Irons', 777372096.0),
#  ('Charlotte Rampling', 777372096.0),
#  ('Lulu Wilson', 773595894.0),
#  ('Jodie Foster', 772434084.0),
#  ('Thandie Newton', 769653595.0),
#  ('Michelle Dockery', 761278352.0),
#  ('Amy Schumer', 760169304.0),
#  ('Imelda Staunton', 758539785.0),
#  ('Mackenzie Foy', 758034568.0),
#  ('John Michael Higgins', 754313530.0),
#  ('Toni Collette', 748142952.0),
#  ('Ali Larter', 748116848.0),
#  ('Damon Wayans Jr.', 746894448.0),
#  ('Timothy Olyphant', 743601390.0),
#  ('Noah Johnston', 743559607.0),
#  ('Chris Messina', 743176065.0),
#  ('Dane Cook', 741908998.0),
#  ('Zazie Beetz', 741547413.0),
#  ('Julian Dennison', 741547413.0),
#  ('Karan Soni', 741547413.0),
#  ('50 Cent', 736182045.0),
#  ('Dominic West', 735866814.0),
#  ('Ed Asner', 735099082.0),
#  ('Jordan Nagai', 735099082.0),
#  ('Bob Peterson', 735099082.0),
#  ('Delroy Lindo', 735099082.0),
#  ('Max von Sydow', 731834842.0),
#  ('Naomi Watts', 727975074.0),
#  ('Bella Thorne', 725551764.0),
#  ('Sarah Paulson', 717114070.0),
#  ('Orto Ignatiussen', 716392705.0),
#  ('Phaldut Sharma', 716392705.0),
#  ('Philip Seymour Hoffman', 711319533.0),
#  ('Ty Burrell', 706591440.0),
#  ('Barbra Streisand', 705028622.0),
#  ('Dermot Mulroney', 702550704.0),
#  ("Catherine O'Hara", 700603632.0),
#  ('Sophia Lillis', 700381748.0),
#  ('Finn Wolfhard', 700381748.0),
#  ('Mark Rylance', 697647874.0),
#  ("Auli'i Cravalho", 695331111.0),
#  ('Rachel House', 695331111.0),
#  ('Temuera Morrison', 695331111.0),
#  ('Ana de Armas', 690948362.0),
#  ('Elisabeth Moss', 689388232.0),
#  ('Patton Oswalt', 686571744.0),
#  ('Clancy Brown', 683443990.0),
#  ('Mads Mikkelsen', 677700000.0),
#  ('Jennifer Jason Leigh', 674493096.0),
#  ('Scott Glenn', 673648618.0),
#  ('Kenneth Branagh', 671574060.0),
#  ('Janet McTeer', 671351622.0),
#  ('Annabelle Wallis', 664295322.0),
#  ('Malin Åkerman', 664208318.0),
#  ('Ashley Tisdale', 662575842.0),
#  ('Ezra Miller', 657924295.0),
#  ('Scott Adsit', 657818612.0),
#  ('Ryan Potter', 657818612.0),
#  ('Daniel Henney', 657818612.0),
#  ('Élodie Yung', 654535130.0),
#  ('Alison Sudol', 653355901.0),
#  ('Jerry Ferrara', 646546017.0),
#  ('Caleb Landry Jones', 646292118.0),
#  ('Daniel Day-Lewis', 646100080.0),
#  ('Christopher Eccleston', 644571402.0),
#  ('Jessica Biel', 642862838.0),
#  ('Joe Manganiello', 639393206.0),
#  ('Alan Alda', 636817942.0),
#  ('Lucy Liu', 631744560.0),
#  ('Dakota Fanning', 624501276.0),
#  ('Cara Delevingne', 622773056.0),
#  ('Courteney Cox', 620026256.0),
#  ('Jordan Peele', 615337456.0),
#  ('Eric Dane', 612010854.0),
#  ('Anika Noni Rose', 609995324.0),
#  ('Ayush Tandon', 609016565.0),
#  ('Gautam Belur', 609016565.0),
#  ('Adil Hussain', 609016565.0),
#  ('Laura Haddock', 605425157.0),
#  ('Dan Aykroyd', 604219146.0),
#  ('Matt Lanter', 604129251.0),
#  ('Emily Watson', 602623134.0),
#  ('Adrien Brody', 601698262.0),
#  ('Florence Pugh', 600245877.0),
#  ('Christine Baranski', 595571906.0),
#  ('Elijah Wood', 594686752.0),
#  ('Sanaa Lathan', 594198957.0),
#  ('Donna Murphy', 591794936.0),
#  ('Delaney Rose Stein', 591794936.0),
#  ('Vanessa Kirby', 591212350.0),
#  ('Barry Pepper', 590414778.0),
#  ('Sally Hawkins', 588391740.0),
#  ('Giancarlo Giannini', 586090727.0),
#  ('Cloris Leachman', 585178928.0),
#  ("Chris O'Dowd", 584439916.0),
#  ('Garrett Hedlund', 583662514.0),
#  ('Henry Golding', 583073956.0),
#  ('Tye Sheridan', 582890172.0),
#  ('Lena Waithe', 582890172.0),
#  ('Jim Sturgess', 582846718.0),
#  ('Hayden Christensen', 582573762.0),
#  ('Lainie Kazan', 581039118.0),
#  ('Zoë Kravitz', 577799796.0),
#  ('Anya Taylor-Joy', 574731820.0),
#  ('Art Parkinson', 574107650.0),
#  ('T.I.', 571552926.0),
#  ('Jennifer Ehle', 571006128.0),
#  ('Victor Rasuk', 571006128.0),
#  ('Cary Elwes', 567861748.0),
#  ('Brandon T. Jackson', 566931458.0),
#  ('Jing Tian', 566652812.0),
#  ('Sophie Okonedo', 563897044.0),
#  ('Tim Gunn', 563749323.0),
#  ('Scott Speedman', 557011430.0),
#  ('Kurt Russell', 555100980.0),
#  ('Billy Bob Thornton', 554987477.0),
#  ('Amy Sedaris', 554987477.0),
#  ('Glenn Morshower', 549003028.0),
#  ('Adam Devine', 543265836.0),
#  ('Cole Konis', 542307423.0),
#  ('Ben Reed', 542307423.0),
#  ('Jeffrey Dean Morgan', 541410116.0),
#  ('Gina Rodriguez', 540183864.0),
#  ('Kelly Macdonald', 538983207.0),
#  ('Billy Connolly', 538983207.0),
#  ('Robbie Coltrane', 538983207.0),
#  ('Cillian Murphy', 535502708.0),
#  ('Paul Anderson', 532950503.0),
#  ('Abigail Hargrove', 531865000.0),
#  ('Kaley Cuoco', 527507206.0),
#  ('Fionn Whitehead', 525573161.0),
#  ('Tom Glynn-Carney', 525573161.0),
#  ('Aneurin Barnard', 525573161.0),
#  ('Jack Lowden', 525573161.0),
#  ('Harry Styles', 525573161.0),
#  ('Steve Martin', 523061134.0),
#  ('Peter Sarsgaard', 522894846.0),
#  ('Levi Miller', 522128368.0),
#  ('Annie Potts', 519802847.0),
#  ('Tony Hale', 519802847.0),
#  ('Rashida Jones', 513642446.0),
#  ("Jack O'Connell", 513451082.0),
#  ('James Cromwell', 511755256.0),
#  ('Renée Zellweger', 506503824.0),
#  ('Maggie Gyllenhaal', 505544606.0),
#  ('Tracy Letts', 502723462.0),
#  ('James Gandolfini', 500505838.0),
#  ('Miles Bakshi', 498814908.0),
#  ('Jimmy Kimmel', 498814908.0),
#  ('Lisa Kudrow', 498814908.0),
#  ('Liv Tyler', 492206438.0),
#  ('Steve Whitmire', 491135054.0),
#  ('Matthew Fox', 490214514.0),
#  ('Rene Russo', 489729344.0),
#  ('Karin Konoval', 488533726.0),
#  ('Terry Notary', 488533726.0),
#  ('Maggie Smith', 487615684.0),
#  ('Bruno Ganz', 487611374.0),
#  ('Will.i.am', 484635760.0),
#  ('Treat Williams', 484564454.0),
#  ('Brian Cox', 482860185.0),
#  ('Kathryn Newton', 472985556.0),
#  ('Jessica Lange', 470571400.0),
#  ('Ioan Gruffudd', 470490832.0),
#  ('Archie Panjabi', 470490832.0),
#  ('Isabela Moner', 467048109.0),
#  ('George Lopez', 466086900.0),
#  ('Jorge Lendeborg Jr.', 465895025.0),
#  ('Jason Ian Drucker', 465895025.0),
#  ('Pamela Adlon', 465895025.0),
#  ('Bette Midler', 464511992.0),
#  ('Donald Sutherland', 464391490.0),
#  ('Anna Friel', 461076572.0),
#  ('Tim Roth', 460999964.0),
#  ('Heather Graham', 459270619.0),
#  ('Imogen Poots', 458653436.0),
#  ('Sarah Bolger', 453900790.0),
#  ('Kevin Connolly', 453045690.0),
#  ('Odeya Rush', 450286488.0),
#  ('Mary-Louise Parker', 448976334.0),
#  ('K.J. Apa', 447621716.0),
#  ('Al Pacino', 445696708.0),
#  ('John Legend', 445435700.0),
#  ('Joey King', 434368024.0),
#  ('Travis Fimmel', 433677183.0),
#  ('Robert Kazinsky', 433677183.0),
#  ('John Slattery', 432431704.0),
#  ('Jake Johnson', 423442542.0),
#  ('Luke Bracey', 422457134.0),
#  ('William Moseley', 419665568.0),
#  ('Anna Popplewell', 419665568.0),
#  ('Eugenio Derbez', 418392868.0),
#  ('Jillian Bell', 415619352.0),
#  ('Julia Stiles', 415484914.0),
#  ('Will Yun Lee', 415440673.0),
#  ('Tao Okamoto', 415440673.0),
#  ('Timothy Spall', 414211549.0),
#  ('Annalise Basso', 412659801.0),
#  ('Taron Egerton', 410902662.0),
#  ('Rinko Kikuchi', 407602906.0),
#  ('Clifton Collins Jr.', 407602906.0),
#  ('John Hannah', 401128639.0),
#  ('Luke Ford', 401128639.0),
#  ('Ed Oxenbould', 398208422.0),
#  ('Geoff Pierson', 395252570.0),
#  ('Henry Thomas', 393365700.0),
#  ('Joonas Suotamo', 392952373.0),
#  ('Rob Reiner', 392000694.0),
#  ('Sela Ward', 389681935.0),
#  ('Alex Roe', 385974524.0),
#  ('Millie Bobby Brown', 385900138.0),
#  ('Zhang Ziyi', 385900138.0),
#  ('Ryan Guzman', 385793202.0),
#  ('Leonard Nimoy', 385680446.0),
#  ('Cristela Alonzo', 383925276.0),
#  ('Nathan Fillion', 383925276.0),
#  ('Toby Jones', 383443116.0),
#  ('David Wenham', 379733860.0),
#  ('Essie Davis', 379254784.0),
#  ('Hugh Keays-Byrne', 378858340.0),
#  ('Josh Helman', 378858340.0),
#  ('Bella Heathcote', 378827494.0),
#  ('Angourie Rice', 378669472.0),
#  ('Linda Emond', 378185742.0),
#  ('Anil Kapoor', 377910544.0),
#  ('Mia Drake Inderbitzin', 377910544.0),
#  ('Saurabh Shukla', 377910544.0),
#  ('Julie Bowen', 377752794.0),
#  ('Jeffrey Donovan', 377713876.0),
#  ('Maggie Grace', 376141306.0),
#  ('Óscar Jaenada', 374284272.0),
#  ('Tom McGrath', 373552094.0),
#  ('Chris Miller', 373552094.0),
#  ('Christopher Knights', 373552094.0),
#  ('Conrad Vernon', 373552094.0),
#  ('D.J. Cotrona', 371876278.0),
#  ('Adrianne Palicki', 371876278.0),
#  ('Ray Park', 371876278.0),
#  ('Anton Yelchin', 371353001.0),
#  ('Moon Bloodgood', 371353001.0),
#  ('Matt Bomer', 370602550.0),
#  ('Hayley Atwell', 370569774.0),
#  ('Hugo Weaving', 370569774.0),
#  ('Jonas Armstrong', 370541256.0),
#  ('Carrie Coon', 369330363.0),
#  ('Rita Ora', 368307760.0),
#  ('Fran Kranz', 367948052.0),
#  ('Taissa Farmiga', 365550119.0),
#  ('Jonas Bloquet', 365550119.0),
#  ('Bonnie Aarons', 365550119.0),
#  ('Ingrid Bisu', 365550119.0),
#  ('Asher Angel', 363533271.0),
#  ('Fran Drescher', 358375603.0),
#  ('Kathy Bates', 358323378.0),
#  ('Yu Rong-Guang', 357852395.0),
#  ('Tess Liu', 357852395.0),
#  ('Carmen Ejogo', 357432546.0),
#  ('Ayelet Zurer', 356613439.0),
#  ('Pierfrancesco Favino', 356613439.0),
#  ('Dee Bradley Baker', 353077228.0),
#  ('Topher Grace', 349870836.0),
#  ('Lin-Manuel Miranda', 348807090.0),
#  ('Pixie Davies', 348807090.0),
#  ('Aml Ameen', 348300000.0),
#  ('Blake Cooper', 348300000.0),
#  ('Jonathan Winters', 347434178.0),
#  ('Andy Buckley', 342695435.0),
#  ('Aubrey Plaza', 342282548.0),
#  ('Millicent Simmonds', 340677200.0),
#  ('Noah Jupe', 340677200.0),
#  ('Cade Woodward', 340677200.0),
#  ('Tiffany Haddish', 339058478.0),
#  ('Michael Kenneth Williams', 338279937.0),
#  ('Gemma Arterton', 335154643.0),
#  ('Steve Toussaint', 335154643.0),
#  ('Julia Ormond', 333932083.0),
#  ('Raymond Ochoa', 331926147.0),
#  ('Jack Bright', 331926147.0),
#  ('Jeffrey Wright', 331926147.0),
#  ('Maleah Nipay-Padilla', 331926147.0),
#  ('Barbara Hershey', 327803731.0),
#  ('Emilio Rivera', 326480432.0),
#  ('Mark Dacascos', 323398440.0),
#  ('Matt Dillon', 322550010.0),
#  ('Madison Wolfe', 320170008.0),
#  ("Frances O'Connor", 320170008.0),
#  ('Benicio del Toro', 319724998.0),
#  ('Viggo Mortensen', 319700000.0),
#  ('Dimiter D. Marinov', 319700000.0),
#  ('Mike Hatton', 319700000.0),
#  ('Sean Penn', 319574974.0),
#  ('Lili Taylor', 319494638.0),
#  ('Eli Roth', 319131050.0),
#  ('Noah Ringer', 318502923.0),
#  ('Jackson Rathbone', 318502923.0),
#  ('Shaun Toub', 318502923.0),
#  ('Betty White', 317375031.0),
#  ('Krysten Ritter', 316224942.0),
#  ('Ruby Rose', 315960074.0),
#  ('Danny Trejo', 315153424.0),
#  ('John Gallagher Jr.', 314210288.0),
#  ('Aaron Taylor-Johnson', 313777806.0),
#  ('Jean-Claude Van Damme', 312573423.0),
#  ('Christopher Meloni', 311731848.0),
#  ('Tom Kenny', 311594032.0),
#  ('Bill Fagerbakke', 311594032.0),
#  ('Rodger Bumpass', 311594032.0),
#  ('Carolyn Lawrence', 311594032.0),
#  ('Giancarlo Esposito', 311256926.0),
#  ('Aidan Gillen', 311256926.0),
#  ('Susie Essman', 309979994.0),
#  ('Mark Walton', 309979994.0),
#  ('Malcolm McDowell', 309979994.0),
#  ('Quinton Aaron', 309208309.0),
#  ('AnnaSophia Robb', 306785956.0),
#  ('Stephanie Sigman', 305092201.0),
#  ('Talitha Bateman', 305092201.0),
#  ('Anthony LaPaglia', 305092201.0),
#  ('Miranda Otto', 305092201.0),
#  ('Jai Courtney', 304654182.0),
#  ('Yuliya Snigir', 304654182.0),
#  ('Terry Crews', 304651510.0),
#  ('Lucas Hedges', 303770476.0),
#  ('Marin Ireland', 303740694.0),
#  ('Max Irons', 301563870.0),
#  ('Wentworth Miller', 300228084.0),
#  ('Kim Coates', 300228084.0),
#  ('Kacey Clarke', 300228084.0),
#  ('Pablo Schreiber', 299841984.0),
#  ('Alan Rickman', 299457024.0),
#  ('Dakota Goyo', 299268508.0),
#  ('Kevin Durand', 299268508.0),
#  ('Beau Bridges', 296498228.0),
#  ('Eva Green', 296485719.0),
#  ('Rupert Everett', 296485719.0),
#  ('Stephanie Szostak', 296072714.0),
#  ('Jessica Rothe', 295930756.0),
#  ('Israel Broussard', 295930756.0),
#  ('Ruby Modine', 295930756.0),
#  ('Harry Connick Jr.', 295657860.0),
#  ('Nathan Gamble', 295657860.0),
#  ('David Tennant', 295038508.0),
#  ('Bianca A. Santos', 294237810.0),
#  ('Daniel Olbrychski', 293329073.0),
#  ('August Diehl', 293329073.0),
#  ('Chin Han', 292351275.0),
#  ('Noah Taylor', 292351275.0),
#  ('Byron Mann', 292351275.0),
#  ('Alexis Dziena', 288409956.0),
#  ('Mare Winningham', 286896442.0),
#  ('Andrea Riseborough', 286168572.0),
#  ('Jeremy Strong', 286006806.0),
#  ('Kodi Smit-McPhee', 285895672.0),
#  ('Katee Sackhoff', 284735082.0),
#  ('Samantha Morton', 284139100.0),
#  ('Cam Gigandet', 284130960.0),
#  ('John Corbett', 282698212.0),
#  ('Paul Bettany', 278731369.0),
#  ('Timothy Dalton', 278731369.0),
#  ('Steven Berkoff', 278731369.0),
#  ('Jenna Fischer', 278623382.0),
#  ('Stacy Keach', 276572938.0),
#  ('Fred Dalton Thompson', 275927620.0),
#  ('Sally Field', 275293450.0),
#  ('David Strathairn', 275293450.0),
#  ('James Spader', 275293450.0),
#  ('Daniel Wu', 274650803.0),
#  ...]

# %%
actor_ranking = {}
i = 1
for info in sorted_actors:
    if actor_ranking.get(info[0]) == None:
        actor_ranking[info[0]] = i
    else:
        actor_ranking[info[0]] += 1
    i = i+1

# %%
actor_ranking
# Out:
# {'Robert Downey Jr.': 1,
#  'Dwayne Johnson': 2,
#  'Scarlett Johansson': 3,
#  'Chris Hemsworth': 4,
#  'Mark Wahlberg': 5,
#  'Bradley Cooper': 6,
#  'Chris Evans': 7,
#  'Jennifer Lawrence': 8,
#  'Woody Harrelson': 9,
#  'Mark Ruffalo': 10,
#  'Samuel L. Jackson': 11,
#  'Vin Diesel': 12,
#  'Simon Pegg': 13,
#  'Emma Stone': 14,
#  'Ryan Reynolds': 15,
#  'Chris Pratt': 16,
#  'Steve Carell': 17,
#  'Johnny Depp': 18,
#  'Tom Cruise': 19,
#  'Kevin Hart': 20,
#  'Gary Oldman': 21,
#  'Christian Bale': 22,
#  'Jason Bateman': 23,
#  'John Goodman': 24,
#  'Harrison Ford': 25,
#  'Owen Wilson': 26,
#  'Chris Pine': 27,
#  'Cate Blanchett': 28,
#  'Tom Hanks': 29,
#  'Matt Damon': 30,
#  'Zoe Saldana': 31,
#  'Kristen Wiig': 32,
#  'Ben Stiller': 33,
#  'Elizabeth Banks': 34,
#  'Jonah Hill': 35,
#  'Adam Sandler': 36,
#  'Michael Fassbender': 37,
#  'Amy Adams': 38,
#  'Anne Hathaway': 39,
#  'Angelina Jolie': 40,
#  'Jason Statham': 41,
#  'Christoph Waltz': 42,
#  'Jack Black': 43,
#  'Gerard Butler': 44,
#  'Liam Neeson': 45,
#  'Hugh Jackman': 46,
#  'Jessica Chastain': 47,
#  'Josh Hutcherson': 48,
#  'Anna Kendrick': 49,
#  'George Clooney': 50,
#  'Rachel McAdams': 51,
#  'Michelle Rodriguez': 52,
#  'Emily Blunt': 53,
#  'Sam Worthington': 54,
#  'Daniel Craig': 55,
#  'Meryl Streep': 56,
#  'Kevin James': 57,
#  'John Leguizamo': 58,
#  'Idris Elba': 59,
#  'Bryce Dallas Howard': 60,
#  'Ben Affleck': 61,
#  'Martin Freeman': 62,
#  'Bill Hader': 63,
#  'Jesse Eisenberg': 64,
#  'Tyrese Gibson': 65,
#  'James McAvoy': 66,
#  'Charlize Theron': 67,
#  'Michael Keaton': 68,
#  'Jon Favreau': 69,
#  'Brad Pitt': 70,
#  'Amanda Seyfried': 71,
#  'Sandra Bullock': 72,
#  'T.J. Miller': 73,
#  'Mila Kunis': 74,
#  'Jeremy Renner': 75,
#  'Ralph Fiennes': 76,
#  'Zac Efron': 77,
#  'Leonardo DiCaprio': 78,
#  'Michael Caine': 79,
#  'Tom Hardy': 80,
#  'Rose Byrne': 81,
#  'Will Ferrell': 82,
#  'Matthew McConaughey': 83,
#  'Mark Strong': 84,
#  'Zach Galifianakis': 85,
#  'Evangeline Lilly': 86,
#  'Robert De Niro': 87,
#  'Liam Hemsworth': 88,
#  'Josh Duhamel': 89,
#  'Tom Hiddleston': 90,
#  'Andy Samberg': 91,
#  'Jude Law': 92,
#  'Henry Cavill': 93,
#  'Jason Sudeikis': 94,
#  'Jake Gyllenhaal': 95,
#  'Patrick Wilson': 96,
#  'Jamie Foxx': 97,
#  'Vera Farmiga': 98,
#  'Seth Rogen': 99,
#  'Shia LaBeouf': 100,
#  'Jason Segel': 101,
#  'Ken Jeong': 102,
#  'Benedict Cumberbatch': 103,
#  'Adam Driver': 104,
#  'Kristen Bell': 105,
#  'Helen Mirren': 106,
#  'Paul Rudd': 107,
#  'Channing Tatum': 108,
#  'Josh Gad': 109,
#  'Michael Peña': 110,
#  'Morgan Freeman': 111,
#  'Ian McShane': 112,
#  'Frances McDormand': 113,
#  'Leslie Mann': 114,
#  'Jeff Bridges': 115,
#  'Bruce Willis': 116,
#  'Jenny Slate': 117,
#  'Josh Brolin': 118,
#  'Denzel Washington': 119,
#  'Jackie Chan': 120,
#  'Paul Walker': 121,
#  'John C. Reilly': 122,
#  'John Malkovich': 123,
#  'Denis Leary': 124,
#  'Cameron Diaz': 125,
#  'Sebastian Stan': 126,
#  'Ed Helms': 127,
#  'Will Smith': 128,
#  'Gal Gadot': 129,
#  'Guy Pearce': 130,
#  'Joseph Gordon-Levitt': 131,
#  'Sylvester Stallone': 132,
#  'Dustin Hoffman': 133,
#  'Judi Dench': 134,
#  'Anthony Hopkins': 135,
#  'Don Cheadle': 136,
#  'Seann William Scott': 137,
#  'Reese Witherspoon': 138,
#  'Ryan Gosling': 139,
#  'Stanley Tucci': 140,
#  'Richard Jenkins': 141,
#  'Queen Latifah': 142,
#  'Gwyneth Paltrow': 143,
#  'Anthony Mackie': 144,
#  'Chiwetel Ejiofor': 145,
#  'Natalie Portman': 146,
#  'Russell Crowe': 147,
#  'Margot Robbie': 148,
#  'Justin Timberlake': 149,
#  'Jay Baruchel': 150,
#  'Michael B. Jordan': 151,
#  'Stephen Lang': 152,
#  'Catherine Keener': 153,
#  'Aaron Eckhart': 154,
#  'Sigourney Weaver': 155,
#  'Ray Romano': 156,
#  'Jennifer Aniston': 157,
#  'Ian McKellen': 158,
#  'Richard Armitage': 159,
#  'Kristen Stewart': 160,
#  'Jon Hamm': 161,
#  'Andy Serkis': 162,
#  'Hailee Steinfeld': 163,
#  'Brendan Gleeson': 164,
#  'Steve Buscemi': 165,
#  'Russell Brand': 166,
#  'J.K. Simmons': 167,
#  'Rebecca Ferguson': 168,
#  'Sharlto Copley': 169,
#  'Domhnall Gleeson': 170,
#  'Alec Baldwin': 171,
#  "Vincent D'Onofrio": 172,
#  'Robert Pattinson': 173,
#  'Dakota Johnson': 174,
#  'Danny McBride': 175,
#  'Nick Robinson': 176,
#  'Irrfan Khan': 177,
#  'Chris Rock': 178,
#  'Andrew Garfield': 179,
#  'Justin Long': 180,
#  'Joan Cusack': 181,
#  'Chloë Grace Moretz': 182,
#  'Viola Davis': 183,
#  'Kevin Costner': 184,
#  'Craig T. Nelson': 185,
#  'Anna Faris': 186,
#  'Kaya Scodelario': 187,
#  'Paula Patton': 188,
#  'Mark Hamill': 189,
#  'Carrie Fisher': 190,
#  'Daisy Ridley': 191,
#  'Lake Bell': 192,
#  'Geoffrey Rush': 193,
#  'Eric Bana': 194,
#  'Taraji P. Henson': 195,
#  'America Ferrera': 196,
#  'Nicholas Hoult': 197,
#  'Colin Firth': 198,
#  'Sam Rockwell': 199,
#  'Bryan Cranston': 200,
#  'Allison Janney': 201,
#  'Javier Bardem': 202,
#  'Vince Vaughn': 203,
#  'Naomie Harris': 204,
#  'Bobby Cannavale': 205,
#  'Kyle Chandler': 206,
#  'Hank Azaria': 207,
#  'Seth MacFarlane': 208,
#  'Elle Fanning': 209,
#  'Nicole Kidman': 210,
#  "Dylan O'Brien": 211,
#  'Ben Kingsley': 212,
#  'Neil Patrick Harris': 213,
#  'Toby Kebbell': 214,
#  'Taylor Lautner': 215,
#  "Lupita Nyong'o": 216,
#  'Casey Affleck': 217,
#  'Jennifer Connelly': 218,
#  'Rebel Wilson': 219,
#  'Thomas Haden Church': 220,
#  'Eddie Marsan': 221,
#  'Dev Patel': 222,
#  'Maya Rudolph': 223,
#  'Robin Wright': 224,
#  'Zachary Quinto': 225,
#  'Will Arnett': 226,
#  'Will Poulter': 227,
#  'Julia Roberts': 228,
#  'Billy Burke': 229,
#  'Dave Bautista': 230,
#  'Marisa Tomei': 231,
#  'Walton Goggins': 232,
#  'Carla Gugino': 233,
#  'Craig Ferguson': 234,
#  'Tessa Thompson': 235,
#  'Diane Keaton': 236,
#  'Melissa McCarthy': 237,
#  'James Franco': 238,
#  'Ving Rhames': 239,
#  'Katherine Heigl': 240,
#  'John Turturro': 241,
#  'David Cross': 242,
#  'Rebecca Hall': 243,
#  'Halle Berry': 244,
#  'Nick Nolte': 245,
#  'Michelle Monaghan': 246,
#  'Ed Harris': 247,
#  'John Krasinski': 248,
#  'Michelle Williams': 249,
#  'Willem Dafoe': 250,
#  'Amy Poehler': 251,
#  'James Corden': 252,
#  'Rami Malek': 253,
#  'Stellan Skarsgård': 254,
#  'Julie Andrews': 255,
#  'Brenton Thwaites': 256,
#  'Luke Evans': 257,
#  'Felicity Jones': 258,
#  'Zachary Levi': 259,
#  'Helena Bonham Carter': 260,
#  'Diego Luna': 261,
#  'Daniel Radcliffe': 262,
#  'Penélope Cruz': 263,
#  'Giovanni Ribisi': 264,
#  'Emma Watson': 265,
#  'Karl Urban': 266,
#  'Tommy Lee Jones': 267,
#  'Rainn Wilson': 268,
#  'Tom Holland': 269,
#  'Steve Coogan': 270,
#  'Robin Williams': 271,
#  'Teresa Palmer': 272,
#  'Miranda Cosgrove': 273,
#  'Dana Gaier': 274,
#  'Jamie Dornan': 275,
#  'Blake Lively': 276,
#  'Joel Edgerton': 277,
#  'Pierce Brosnan': 278,
#  'Amber Heard': 279,
#  'Jason Clarke': 280,
#  'Danny Huston': 281,
#  'Nicolas Cage': 282,
#  'Amy Ryan': 283,
#  'Mary Steenburgen': 284,
#  'Ben Foster': 285,
#  'Kathryn Hahn': 286,
#  'Demián Bichir': 287,
#  'Djimon Hounsou': 288,
#  'Tina Fey': 289,
#  'Emily Mortimer': 290,
#  'Jason Momoa': 291,
#  'Nick Frost': 292,
#  'Jack McBrayer': 293,
#  'Dominic Cooper': 294,
#  'Colin Farrell': 295,
#  'Jack Reynor': 296,
#  'Amanda Peet': 297,
#  'Benjamin Bratt': 298,
#  'Megan Fox': 299,
#  'Edward Norton': 300,
#  'Octavia Spencer': 301,
#  'Jennifer Garner': 302,
#  'Ellie Kemper': 303,
#  'Billy Crudup': 304,
#  'Sacha Baron Cohen': 305,
#  'Christina Applegate': 306,
#  'Jayma Mays': 307,
#  'Freida Pinto': 308,
#  'Jamie Bell': 309,
#  'Justin Bartha': 310,
#  'Liev Schreiber': 311,
#  'Dave Franco': 312,
#  'Taylor Kitsch': 313,
#  'Zooey Deschanel': 314,
#  'Tim Allen': 315,
#  'Ray Winstone': 316,
#  'Zendaya': 317,
#  'Susan Sarandon': 318,
#  'Isla Fisher': 319,
#  'Vanessa Hudgens': 320,
#  'Joel Kinnaman': 321,
#  'Regina Hall': 322,
#  'Alan Tudyk': 323,
#  'Laurence Fishburne': 324,
#  'Jane Lynch': 325,
#  'Cedric the Entertainer': 326,
#  'Rosamund Pike': 327,
#  'Salma Hayek': 328,
#  'Campbell Scott': 329,
#  'Jemaine Clement': 330,
#  'Chadwick Boseman': 331,
#  'Eddie Redmayne': 332,
#  'Kate McKinnon': 333,
#  'Katie Featherston': 334,
#  'Sofía Vergara': 335,
#  'Marion Cotillard': 336,
#  'Jordana Brewster': 337,
#  'Nicola Peltz': 338,
#  'Ice Cube': 339,
#  'Ashley Greene': 340,
#  'Selena Gomez': 341,
#  'Michael Shannon': 342,
#  'Ewan McGregor': 343,
#  'Mary Elizabeth Winstead': 344,
#  'Joel David Moore': 345,
#  'Jada Pinkett Smith': 346,
#  'Danai Gurira': 347,
#  'Dennis Quaid': 348,
#  'Justice Smith': 349,
#  'Jon Bernthal': 350,
#  'Olivia Wilde': 351,
#  'Simon McBurney': 352,
#  'Ben Mendelsohn': 353,
#  'David Schwimmer': 354,
#  'Ned Beatty': 355,
#  'Antonio Banderas': 356,
#  'Holly Hunter': 357,
#  'Jeff Daniels': 358,
#  'Jim Carrey': 359,
#  'John Cena': 360,
#  'Kelsey Grammer': 361,
#  'Alexandra Daddario': 362,
#  'Jet Li': 363,
#  'Christopher Plummer': 364,
#  'Lily James': 365,
#  'Bill Nighy': 366,
#  'Abigail Breslin': 367,
#  'Abbie Cornish': 368,
#  'Peter Dinklage': 369,
#  'Ken Watanabe': 370,
#  'Alfred Molina': 371,
#  'Ed Skrein': 372,
#  'Sarah Jessica Parker': 373,
#  'Michael Douglas': 374,
#  'Luis Guzmán': 375,
#  'Bill Paxton': 376,
#  'Julianne Moore': 377,
#  'Armie Hammer': 378,
#  'Michael Ealy': 379,
#  'Julie Walters': 380,
#  'Wendi McLendon-Covey': 381,
#  'Emma Roberts': 382,
#  'Kevin Bacon': 383,
#  'Angela Bassett': 384,
#  'Brie Larson': 385,
#  'Ashton Kutcher': 386,
#  'Linda Cardellini': 387,
#  'Melissa Leo': 388,
#  'Alan Arkin': 389,
#  'Paul Giamatti': 390,
#  'Peter Facinelli': 391,
#  'Alicia Vikander': 392,
#  'Alexander Skarsgård': 393,
#  'Ginnifer Goodwin': 394,
#  'Bruce Greenwood': 395,
#  'Jessica Alba': 396,
#  'Phyllis Smith': 397,
#  'Jack Dylan Grazer': 398,
#  'Terrence Howard': 399,
#  'Jaden Smith': 400,
#  'David Harbour': 401,
#  'Britt Robertson': 402,
#  'James Badge Dale': 403,
#  'Aaron Paul': 404,
#  'Emma Thompson': 405,
#  'Eric Stonestreet': 406,
#  'Li Bingbing': 407,
#  'Suraj Sharma': 408,
#  'Maria Bello': 409,
#  'Karen Gillan': 410,
#  'Joel McHale': 411,
#  'Sarah Silverman': 412,
#  'James Marsden': 413,
#  'Tom Felton': 414,
#  'Louis C.K.': 415,
#  'Eloise Mumford': 416,
#  'Kevin Spacey': 417,
#  'Larry the Cable Guy': 418,
#  'Charlie Hunnam': 419,
#  'William Hurt': 420,
#  'Brendan Fraser': 421,
#  'Chris Cooper': 422,
#  'Jae Head': 423,
#  'Dane DeHaan': 424,
#  'David Spade': 425,
#  'Terence Stamp': 426,
#  'Keri Russell': 427,
#  'Tracy Morgan': 428,
#  'Asa Butterfield': 429,
#  'Eddie Murphy': 430,
#  'Kelly Reilly': 431,
#  'Katherine Waterston': 432,
#  'Gael García Bernal': 433,
#  'Milla Jovovich': 434,
#  'Lily Collins': 435,
#  'Brittany Snow': 436,
#  'Nikolaj Coster-Waldau': 437,
#  'Ethan Hawke': 438,
#  'Connie Nielsen': 439,
#  'Olga Kurylenko': 440,
#  'Billy Crystal': 441,
#  'Max Martini': 442,
#  'Michael Cera': 443,
#  'Sienna Miller': 444,
#  'Keanu Reeves': 445,
#  'Tobin Bell': 446,
#  'Adam Scott': 447,
#  'Ben Barnes': 448,
#  'Georgie Henley': 449,
#  'Skandar Keynes': 450,
#  'John Cusack': 451,
#  'Oliver Platt': 452,
#  'John Travolta': 453,
#  'Kevin Kline': 454,
#  'Lizzy Caplan': 455,
#  'Brad Garrett': 456,
#  'Lesley Manville': 457,
#  'Rhys Ifans': 458,
#  'Jared Leto': 459,
#  'Mike Myers': 460,
#  'Jeremy Ray Taylor': 461,
#  'Famke Janssen': 462,
#  'Jason Lee': 463,
#  'Michael Nyqvist': 464,
#  'Marlon Wayans': 465,
#  'Tom Wilkinson': 466,
#  'Patrick Dempsey': 467,
#  'Tyler Perry': 468,
#  'Alice Braga': 469,
#  'Mathieu Amalric': 470,
#  'Rosario Dawson': 471,
#  'Jaeden Martell': 472,
#  'Robert Redford': 473,
#  'Jamie Chung': 474,
#  'Jeff Goldblum': 475,
#  'Eric Johnson': 476,
#  'Luke Grimes': 477,
#  'Vincent Cassel': 478,
#  'Noomi Rapace': 479,
#  'Benedict Wong': 480,
#  'Alex Pettyfer': 481,
#  'Mahershala Ali': 482,
#  'Leslie Bibb': 483,
#  'Ludacris': 484,
#  'Kim Cattrall': 485,
#  'Cynthia Nixon': 486,
#  'Kristin Davis': 487,
#  'Chris Noth': 488,
#  'Ike Barinholtz': 489,
#  'Mel Gibson': 490,
#  'Rosa Salazar': 491,
#  'Olivia Cooke': 492,
#  'Julianne Hough': 493,
#  'Kate Hudson': 494,
#  'Rachel Weisz': 495,
#  'Drew Barrymore': 496,
#  'Forest Whitaker': 497,
#  'John Boyega': 498,
#  'Christopher Mintz-Plasse': 499,
#  'John Lithgow': 500,
#  'Lynn Collins': 501,
#  'Rafe Spall': 502,
#  'Daniella Pineda': 503,
#  'Aldis Hodge': 504,
#  'Andy García': 505,
#  'Keira Knightley': 506,
#  'Mia Wasikowska': 507,
#  'Anthony Anderson': 508,
#  'Idina Menzel': 509,
#  'Jonathan Groff': 510,
#  'Santino Fontana': 511,
#  'Mandy Moore': 512,
#  'Cliff Curtis': 513,
#  'Ki Hong Lee': 514,
#  'Dylan Minnette': 515,
#  'Sarah Vowell': 516,
#  'Eli Fucile': 517,
#  'Huck Milner': 518,
#  'Corey Stoll': 519,
#  'Kyle Gallner': 520,
#  'Mireille Enos': 521,
#  'Olivia Munn': 522,
#  'Bill Murray': 523,
#  'Sam Claflin': 524,
#  'Emilia Clarke': 525,
#  'Thomas Brodie-Sangster': 526,
#  'Saoirse Ronan': 527,
#  'Sterling Jerins': 528,
#  'Jim Broadbent': 529,
#  'Oscar Isaac': 530,
#  'Doug Jones': 531,
#  'Hiroyuki Sanada': 532,
#  'Jennifer Lopez': 533,
#  'Logan Lerman': 534,
#  'Ashley Judd': 535,
#  'Sam Neill': 536,
#  'Clive Owen': 537,
#  'Steve Zahn': 538,
#  'Matthew Broderick': 539,
#  'Charlie Day': 540,
#  'Paul Dano': 541,
#  'Rihanna': 542,
#  'Bruce McGill': 543,
#  'Donnie Yen': 544,
#  'Jiang Wen': 545,
#  'Kevin McNally': 546,
#  'Juliette Lewis': 547,
#  'Arnold Schwarzenegger': 548,
#  'Trey Parker': 549,
#  'Ellen DeGeneres': 550,
#  'Albert Brooks': 551,
#  'Hayden Rolence': 552,
#  "Ed O'Neill": 553,
#  'Rosemarie DeWitt': 554,
#  'Nate Torrence': 555,
#  'James Nesbitt': 556,
#  'Ken Stott': 557,
#  'Rooney Mara': 558,
#  'Radha Mitchell': 559,
#  'Matthew Gray Gubler': 560,
#  'David Oyelowo': 561,
#  'Heath Ledger': 562,
#  'Maika Monroe': 563,
#  'Tilda Swinton': 564,
#  'Douglas Smith': 565,
#  'Bill Pullman': 566,
#  'Meagan Good': 567,
#  'James Caan': 568,
#  'Colm Meaney': 569,
#  "O'Shea Jackson Jr.": 570,
#  'Laura Linney': 571,
#  'Nick Jonas': 572,
#  'Costas Mandylor': 573,
#  'Betsy Russell': 574,
#  'Sebastian Koch': 575,
#  'Rupert Grint': 576,
#  'Michael Gambon': 577,
#  'Cobie Smulders': 578,
#  'Morris Chestnut': 579,
#  'Tika Sumpter': 580,
#  'Frank Grillo': 581,
#  'Rob Corddry': 582,
#  'Donald Glover': 583,
#  'Alden Ehrenreich': 584,
#  'Scoot McNairy': 585,
#  'Jared Harris': 586,
#  'Tadanobu Asano': 587,
#  'Nick Swardson': 588,
#  'Kerry Washington': 589,
#  'Gwilym Lee': 590,
#  'Ben Hardy': 591,
#  'Joseph Mazzello': 592,
#  'Lucy Boynton': 593,
#  'Emile Hirsch': 594,
#  'David Koechner': 595,
#  'Ben Whishaw': 596,
#  'Robert Duvall': 597,
#  'Clint Eastwood': 598,
#  'Léa Seydoux': 599,
#  'Josh Peck': 600,
#  'Mélanie Laurent': 601,
#  'Rade Šerbedžija': 602,
#  'Jackie Earle Haley': 603,
#  'Richard Kind': 604,
#  'Lewis Black': 605,
#  'Charles Dance': 606,
#  'Kristin Scott Thomas': 607,
#  'Ron Livingston': 608,
#  'Miles Teller': 609,
#  'Matthew Goode': 610,
#  'Ryan Lee': 611,
#  'Alison Brie': 612,
#  'Ellen Page': 613,
#  'Dolph Lundgren': 614,
#  'Miley Cyrus': 615,
#  'Ramón Rodríguez': 616,
#  'Michael Sheen': 617,
#  'Ciarán Hinds': 618,
#  'Skylar Astin': 619,
#  'Edgar Ramírez': 620,
#  'Tim McGraw': 621,
#  'Anthony Gonzalez': 622,
#  'Alanna Ubach': 623,
#  'Renée Victor': 624,
#  'Keith David': 625,
#  'Winona Ryder': 626,
#  'Kate Winslet': 627,
#  'Karen Allen': 628,
#  'Morena Baccarin': 629,
#  'Gina Carano': 630,
#  'Greg Kinnear': 631,
#  'Katie Holmes': 632,
#  'Neve Campbell': 633,
#  'Jeremy Irons': 634,
#  'Charlotte Rampling': 635,
#  'Lulu Wilson': 636,
#  'Jodie Foster': 637,
#  'Thandie Newton': 638,
#  'Michelle Dockery': 639,
#  'Amy Schumer': 640,
#  'Imelda Staunton': 641,
#  'Mackenzie Foy': 642,
#  'John Michael Higgins': 643,
#  'Toni Collette': 644,
#  'Ali Larter': 645,
#  'Damon Wayans Jr.': 646,
#  'Timothy Olyphant': 647,
#  'Noah Johnston': 648,
#  'Chris Messina': 649,
#  'Dane Cook': 650,
#  'Zazie Beetz': 651,
#  'Julian Dennison': 652,
#  'Karan Soni': 653,
#  '50 Cent': 654,
#  'Dominic West': 655,
#  'Ed Asner': 656,
#  'Jordan Nagai': 657,
#  'Bob Peterson': 658,
#  'Delroy Lindo': 659,
#  'Max von Sydow': 660,
#  'Naomi Watts': 661,
#  'Bella Thorne': 662,
#  'Sarah Paulson': 663,
#  'Orto Ignatiussen': 664,
#  'Phaldut Sharma': 665,
#  'Philip Seymour Hoffman': 666,
#  'Ty Burrell': 667,
#  'Barbra Streisand': 668,
#  'Dermot Mulroney': 669,
#  "Catherine O'Hara": 670,
#  'Sophia Lillis': 671,
#  'Finn Wolfhard': 672,
#  'Mark Rylance': 673,
#  "Auli'i Cravalho": 674,
#  'Rachel House': 675,
#  'Temuera Morrison': 676,
#  'Ana de Armas': 677,
#  'Elisabeth Moss': 678,
#  'Patton Oswalt': 679,
#  'Clancy Brown': 680,
#  'Mads Mikkelsen': 681,
#  'Jennifer Jason Leigh': 682,
#  'Scott Glenn': 683,
#  'Kenneth Branagh': 684,
#  'Janet McTeer': 685,
#  'Annabelle Wallis': 686,
#  'Malin Åkerman': 687,
#  'Ashley Tisdale': 688,
#  'Ezra Miller': 689,
#  'Scott Adsit': 690,
#  'Ryan Potter': 691,
#  'Daniel Henney': 692,
#  'Élodie Yung': 693,
#  'Alison Sudol': 694,
#  'Jerry Ferrara': 695,
#  'Caleb Landry Jones': 696,
#  'Daniel Day-Lewis': 697,
#  'Christopher Eccleston': 698,
#  'Jessica Biel': 699,
#  'Joe Manganiello': 700,
#  'Alan Alda': 701,
#  'Lucy Liu': 702,
#  'Dakota Fanning': 703,
#  'Cara Delevingne': 704,
#  'Courteney Cox': 705,
#  'Jordan Peele': 706,
#  'Eric Dane': 707,
#  'Anika Noni Rose': 708,
#  'Ayush Tandon': 709,
#  'Gautam Belur': 710,
#  'Adil Hussain': 711,
#  'Laura Haddock': 712,
#  'Dan Aykroyd': 713,
#  'Matt Lanter': 714,
#  'Emily Watson': 715,
#  'Adrien Brody': 716,
#  'Florence Pugh': 717,
#  'Christine Baranski': 718,
#  'Elijah Wood': 719,
#  'Sanaa Lathan': 720,
#  'Donna Murphy': 721,
#  'Delaney Rose Stein': 722,
#  'Vanessa Kirby': 723,
#  'Barry Pepper': 724,
#  'Sally Hawkins': 725,
#  'Giancarlo Giannini': 726,
#  'Cloris Leachman': 727,
#  "Chris O'Dowd": 728,
#  'Garrett Hedlund': 729,
#  'Henry Golding': 730,
#  'Tye Sheridan': 731,
#  'Lena Waithe': 732,
#  'Jim Sturgess': 733,
#  'Hayden Christensen': 734,
#  'Lainie Kazan': 735,
#  'Zoë Kravitz': 736,
#  'Anya Taylor-Joy': 737,
#  'Art Parkinson': 738,
#  'T.I.': 739,
#  'Jennifer Ehle': 740,
#  'Victor Rasuk': 741,
#  'Cary Elwes': 742,
#  'Brandon T. Jackson': 743,
#  'Jing Tian': 744,
#  'Sophie Okonedo': 745,
#  'Tim Gunn': 746,
#  'Scott Speedman': 747,
#  'Kurt Russell': 748,
#  'Billy Bob Thornton': 749,
#  'Amy Sedaris': 750,
#  'Glenn Morshower': 751,
#  'Adam Devine': 752,
#  'Cole Konis': 753,
#  'Ben Reed': 754,
#  'Jeffrey Dean Morgan': 755,
#  'Gina Rodriguez': 756,
#  'Kelly Macdonald': 757,
#  'Billy Connolly': 758,
#  'Robbie Coltrane': 759,
#  'Cillian Murphy': 760,
#  'Paul Anderson': 761,
#  'Abigail Hargrove': 762,
#  'Kaley Cuoco': 763,
#  'Fionn Whitehead': 764,
#  'Tom Glynn-Carney': 765,
#  'Aneurin Barnard': 766,
#  'Jack Lowden': 767,
#  'Harry Styles': 768,
#  'Steve Martin': 769,
#  'Peter Sarsgaard': 770,
#  'Levi Miller': 771,
#  'Annie Potts': 772,
#  'Tony Hale': 773,
#  'Rashida Jones': 774,
#  "Jack O'Connell": 775,
#  'James Cromwell': 776,
#  'Renée Zellweger': 777,
#  'Maggie Gyllenhaal': 778,
#  'Tracy Letts': 779,
#  'James Gandolfini': 780,
#  'Miles Bakshi': 781,
#  'Jimmy Kimmel': 782,
#  'Lisa Kudrow': 783,
#  'Liv Tyler': 784,
#  'Steve Whitmire': 785,
#  'Matthew Fox': 786,
#  'Rene Russo': 787,
#  'Karin Konoval': 788,
#  'Terry Notary': 789,
#  'Maggie Smith': 790,
#  'Bruno Ganz': 791,
#  'Will.i.am': 792,
#  'Treat Williams': 793,
#  'Brian Cox': 794,
#  'Kathryn Newton': 795,
#  'Jessica Lange': 796,
#  'Ioan Gruffudd': 797,
#  'Archie Panjabi': 798,
#  'Isabela Moner': 799,
#  'George Lopez': 800,
#  'Jorge Lendeborg Jr.': 801,
#  'Jason Ian Drucker': 802,
#  'Pamela Adlon': 803,
#  'Bette Midler': 804,
#  'Donald Sutherland': 805,
#  'Anna Friel': 806,
#  'Tim Roth': 807,
#  'Heather Graham': 808,
#  'Imogen Poots': 809,
#  'Sarah Bolger': 810,
#  'Kevin Connolly': 811,
#  'Odeya Rush': 812,
#  'Mary-Louise Parker': 813,
#  'K.J. Apa': 814,
#  'Al Pacino': 815,
#  'John Legend': 816,
#  'Joey King': 817,
#  'Travis Fimmel': 818,
#  'Robert Kazinsky': 819,
#  'John Slattery': 820,
#  'Jake Johnson': 821,
#  'Luke Bracey': 822,
#  'William Moseley': 823,
#  'Anna Popplewell': 824,
#  'Eugenio Derbez': 825,
#  'Jillian Bell': 826,
#  'Julia Stiles': 827,
#  'Will Yun Lee': 828,
#  'Tao Okamoto': 829,
#  'Timothy Spall': 830,
#  'Annalise Basso': 831,
#  'Taron Egerton': 832,
#  'Rinko Kikuchi': 833,
#  'Clifton Collins Jr.': 834,
#  'John Hannah': 835,
#  'Luke Ford': 836,
#  'Ed Oxenbould': 837,
#  'Geoff Pierson': 838,
#  'Henry Thomas': 839,
#  'Joonas Suotamo': 840,
#  'Rob Reiner': 841,
#  'Sela Ward': 842,
#  'Alex Roe': 843,
#  'Millie Bobby Brown': 844,
#  'Zhang Ziyi': 845,
#  'Ryan Guzman': 846,
#  'Leonard Nimoy': 847,
#  'Cristela Alonzo': 848,
#  'Nathan Fillion': 849,
#  'Toby Jones': 850,
#  'David Wenham': 851,
#  'Essie Davis': 852,
#  'Hugh Keays-Byrne': 853,
#  'Josh Helman': 854,
#  'Bella Heathcote': 855,
#  'Angourie Rice': 856,
#  'Linda Emond': 857,
#  'Anil Kapoor': 858,
#  'Mia Drake Inderbitzin': 859,
#  'Saurabh Shukla': 860,
#  'Julie Bowen': 861,
#  'Jeffrey Donovan': 862,
#  'Maggie Grace': 863,
#  'Óscar Jaenada': 864,
#  'Tom McGrath': 865,
#  'Chris Miller': 866,
#  'Christopher Knights': 867,
#  'Conrad Vernon': 868,
#  'D.J. Cotrona': 869,
#  'Adrianne Palicki': 870,
#  'Ray Park': 871,
#  'Anton Yelchin': 872,
#  'Moon Bloodgood': 873,
#  'Matt Bomer': 874,
#  'Hayley Atwell': 875,
#  'Hugo Weaving': 876,
#  'Jonas Armstrong': 877,
#  'Carrie Coon': 878,
#  'Rita Ora': 879,
#  'Fran Kranz': 880,
#  'Taissa Farmiga': 881,
#  'Jonas Bloquet': 882,
#  'Bonnie Aarons': 883,
#  'Ingrid Bisu': 884,
#  'Asher Angel': 885,
#  'Fran Drescher': 886,
#  'Kathy Bates': 887,
#  'Yu Rong-Guang': 888,
#  'Tess Liu': 889,
#  'Carmen Ejogo': 890,
#  'Ayelet Zurer': 891,
#  'Pierfrancesco Favino': 892,
#  'Dee Bradley Baker': 893,
#  'Topher Grace': 894,
#  'Lin-Manuel Miranda': 895,
#  'Pixie Davies': 896,
#  'Aml Ameen': 897,
#  'Blake Cooper': 898,
#  'Jonathan Winters': 899,
#  'Andy Buckley': 900,
#  'Aubrey Plaza': 901,
#  'Millicent Simmonds': 902,
#  'Noah Jupe': 903,
#  'Cade Woodward': 904,
#  'Tiffany Haddish': 905,
#  'Michael Kenneth Williams': 906,
#  'Gemma Arterton': 907,
#  'Steve Toussaint': 908,
#  'Julia Ormond': 909,
#  'Raymond Ochoa': 910,
#  'Jack Bright': 911,
#  'Jeffrey Wright': 912,
#  'Maleah Nipay-Padilla': 913,
#  'Barbara Hershey': 914,
#  'Emilio Rivera': 915,
#  'Mark Dacascos': 916,
#  'Matt Dillon': 917,
#  'Madison Wolfe': 918,
#  "Frances O'Connor": 919,
#  'Benicio del Toro': 920,
#  'Viggo Mortensen': 921,
#  'Dimiter D. Marinov': 922,
#  'Mike Hatton': 923,
#  'Sean Penn': 924,
#  'Lili Taylor': 925,
#  'Eli Roth': 926,
#  'Noah Ringer': 927,
#  'Jackson Rathbone': 928,
#  'Shaun Toub': 929,
#  'Betty White': 930,
#  'Krysten Ritter': 931,
#  'Ruby Rose': 932,
#  'Danny Trejo': 933,
#  'John Gallagher Jr.': 934,
#  'Aaron Taylor-Johnson': 935,
#  'Jean-Claude Van Damme': 936,
#  'Christopher Meloni': 937,
#  'Tom Kenny': 938,
#  'Bill Fagerbakke': 939,
#  'Rodger Bumpass': 940,
#  'Carolyn Lawrence': 941,
#  'Giancarlo Esposito': 942,
#  'Aidan Gillen': 943,
#  'Susie Essman': 944,
#  'Mark Walton': 945,
#  'Malcolm McDowell': 946,
#  'Quinton Aaron': 947,
#  'AnnaSophia Robb': 948,
#  'Stephanie Sigman': 949,
#  'Talitha Bateman': 950,
#  'Anthony LaPaglia': 951,
#  'Miranda Otto': 952,
#  'Jai Courtney': 953,
#  'Yuliya Snigir': 954,
#  'Terry Crews': 955,
#  'Lucas Hedges': 956,
#  'Marin Ireland': 957,
#  'Max Irons': 958,
#  'Wentworth Miller': 959,
#  'Kim Coates': 960,
#  'Kacey Clarke': 961,
#  'Pablo Schreiber': 962,
#  'Alan Rickman': 963,
#  'Dakota Goyo': 964,
#  'Kevin Durand': 965,
#  'Beau Bridges': 966,
#  'Eva Green': 967,
#  'Rupert Everett': 968,
#  'Stephanie Szostak': 969,
#  'Jessica Rothe': 970,
#  'Israel Broussard': 971,
#  'Ruby Modine': 972,
#  'Harry Connick Jr.': 973,
#  'Nathan Gamble': 974,
#  'David Tennant': 975,
#  'Bianca A. Santos': 976,
#  'Daniel Olbrychski': 977,
#  'August Diehl': 978,
#  'Chin Han': 979,
#  'Noah Taylor': 980,
#  'Byron Mann': 981,
#  'Alexis Dziena': 982,
#  'Mare Winningham': 983,
#  'Andrea Riseborough': 984,
#  'Jeremy Strong': 985,
#  'Kodi Smit-McPhee': 986,
#  'Katee Sackhoff': 987,
#  'Samantha Morton': 988,
#  'Cam Gigandet': 989,
#  'John Corbett': 990,
#  'Paul Bettany': 991,
#  'Timothy Dalton': 992,
#  'Steven Berkoff': 993,
#  'Jenna Fischer': 994,
#  'Stacy Keach': 995,
#  'Fred Dalton Thompson': 996,
#  'Sally Field': 997,
#  'David Strathairn': 998,
#  'James Spader': 999,
#  'Daniel Wu': 1000,
#  ...}

# %% [markdown]
# #### sorted_actors holds the actual scores while actor_ranking holds the ranking for each actor

# %% [markdown]
# ### Repeat the same steps for directors

# %%
director_budget = {}
for i in range(len(df)):
    crew = df.iloc[i,5]
    # cast string into list
    crew_list = ast.literal_eval(crew)
    director = crew_list.get('Director')[0]
    # adding to new dictionary
    if director_budget.get(director) == None:
        director_budget[director] = float(df.iloc[i, 10])
    else:
        director_budget[director] += float(df.iloc[i, 10])

# %%
director_freq = {}
for i in range(len(df)):
    crew = df.iloc[i,5]
    # cast string into list
    crew_list = ast.literal_eval(crew)
    director = crew_list.get('Director')[0]
    # adding to new dictionary
    if director_freq.get(director) == None:
        director_freq[director] = 1
    else:
        director_freq[director] += 1

# %%
director_score = {}
director_list = director_budget.keys()
for director in director_list:
    if director_score.get(director) == None:
            director_score[director] = director_budget.get(director) * director_freq.get(director)
    else:
        director_score[director] += 1
#sort dictionary in DESCENDING order
sorted_directors = sorted(director_score.items(), key=lambda x: x[1], reverse=True)

# %%
sorted_directors
# Out:
# [('Steven Spielberg', 21741376000.0),
#  ('Christopher Nolan', 20578617425.0),
#  ('Michael Bay', 18631429240.0),
#  ('Clint Eastwood', 17705959520.0),
#  ('Zack Snyder', 15686129292.0),
#  ('Ridley Scott', 14102830315.0),
#  ('James Wan', 13158412796.0),
#  ('Bryan Singer', 12918943540.0),
#  ('J.J. Abrams', 12725461212.0),
#  ('Francis Lawrence', 12575481820.0),
#  ('Peter Jackson', 12116195768.0),
#  ('Joe Russo', 9688080402.0),
#  ('Carlos Saldanha', 8666198080.0),
#  ('Todd Phillips', 6868710120.0),
#  ('Brad Bird', 6437277474.0),
#  ('Shawn Levy', 6290314200.0),
#  ('Peter Berg', 6243444910.0),
#  ('Marc Webb', 6235997876.0),
#  ('David Yates', 5832174477.0),
#  ('Jon Favreau', 5719591252.0),
#  ('Ron Howard', 5652602465.0),
#  ('M. Night Shyamalan', 5355709380.0),
#  ('Justin Lin', 5274868023.0),
#  ('Christopher McQuarrie', 5075064558.0),
#  ('Dean DeBlois', 4864586046.0),
#  ('Nicholas Stoller', 4850446326.0),
#  ('Rob Marshall', 4822269792.0),
#  ('Chris Renaud', 4722373416.0),
#  ('F. Gary Gray', 4701271446.0),
#  ('David Leitch', 4285301064.0),
#  ('Tom McGrath', 4273803081.0),
#  ('Jaume Collet-Serra', 4234782222.0),
#  ('Jon M. Chu', 4172856520.0),
#  ('Matt Reeves', 4109826954.0),
#  ('Peyton Reed', 4103931246.0),
#  ('Roland Emmerich', 4094106801.0),
#  ('Jon Watts', 4023234174.0),
#  ('Pierre Coffin', 4004628940.0),
#  ('Sam Mendes', 3978471244.0),
#  ('Jake Kasdan', 3913160595.0),
#  ('Anthony Russo', 3736142134.0),
#  ('Lee Unkrich', 3734991436.0),
#  ('Dennis Dugan', 3478738252.0),
#  ('Adam McKay', 3359012455.0),
#  ('Guillermo del Toro', 3350641784.0),
#  ('James Gunn', 3274169360.0),
#  ('Pete Docter', 3185420512.0),
#  ('Raja Gosnell', 3181395321.0),
#  ('Ryan Coogler', 3040613376.0),
#  ('Sean Anders', 3019140205.0),
#  ('Guy Ritchie', 3014456235.0),
#  ('Paul Feig', 2945065356.0),
#  ('Seth Gordon', 2900621832.0),
#  ('Wes Ball', 2833315587.0),
#  ('Brad Peyton', 2816002068.0),
#  ('Genndy Tartakovsky', 2795335683.0),
#  ('James Cameron', 2787965087.0),
#  ('David Fincher', 2784548283.0),
#  ('Lasse Hallström', 2778110170.0),
#  ('Rian Johnson', 2759003074.0),
#  ('David O. Russell', 2729341312.0),
#  ('Quentin Tarantino', 2700778215.0),
#  ('Denis Villeneuve', 2675121388.0),
#  ('Andrew Stanton', 2625419978.0),
#  ('Martin Scorsese', 2617725147.0),
#  ('Matthew Vaughn', 2582147067.0),
#  ('Seth MacFarlane', 2558402709.0),
#  ('Shane Black', 2556456424.0),
#  ('Peter Farrelly', 2510068180.0),
#  ('David F. Sandberg', 2452482921.0),
#  ('Rawson Marshall Thurber', 2337953811.0),
#  ('Anne Fletcher', 2284713108.0),
#  ('Marc Forster', 2235911454.0),
#  ('Mike Mitchell', 2190592604.0),
#  ('Antoine Fuqua', 2188602268.0),
#  ('Doug Liman', 2178852891.0),
#  ('Jon Turteltaub', 1996938798.0),
#  ('Malcolm D. Lee', 1945306980.0),
#  ('Paul W.S. Anderson', 1842449565.0),
#  ('Paul Greengrass', 1816103409.0),
#  ('Neill Blomkamp', 1804079577.0),
#  ('Tim Story', 1780308280.0),
#  ('McG', 1742776671.0),
#  ('Tim Burton', 1731901968.0),
#  ('Will Gluck', 1730107509.0),
#  ('Andy Muschietti', 1693759038.0),
#  ('Colin Trevorrow', 1671713208.0),
#  ('Olivier Megaton', 1638260127.0),
#  ('James Bobin', 1635073653.0),
#  ('David Ayer', 1587452876.0),
#  ('Rupert Wyatt', 1583968890.0),
#  ('Robert Rodriguez', 1565234256.0),
#  ('Jonathan Levine', 1558183435.0),
#  ('Steven Soderbergh', 1554606384.0),
#  ('Scott Derrickson', 1510824878.0),
#  ('James Foley', 1494270508.0),
#  ('Catherine Hardwicke', 1493936850.0),
#  ('Joe Wright', 1485835864.0),
#  ('Phyllida Lloyd', 1449596672.0),
#  ('Ethan Coen', 1438933956.0),
#  ('Michael Patrick King', 1407200956.0),
#  ('Joss Whedon', 1405403694.0),
#  ('Darren Aronofsky', 1380882408.0),
#  ('Ang Lee', 1337137874.0),
#  ('Martin Campbell', 1320379830.0),
#  ('J. A. Bayona', 1303459585.0),
#  ('Ben Stiller', 1296524913.0),
#  ('Jennifer Lee', 1274219009.0),
#  ('Alejandro González Iñárritu', 1272331194.0),
#  ('Garry Marshall', 1220845356.0),
#  ('Kenneth Branagh', 1169675296.0),
#  ('Duncan Jones', 1162019760.0),
#  ('Kyle Balda', 1156730962.0),
#  ('Robert Luketic', 1119846207.0),
#  ('Damien Chazelle', 1091963706.0),
#  ('Travis Knight', 1071649140.0),
#  ('George Miller', 1058529612.0),
#  ('Gareth Edwards', 1056057273.0),
#  ('Peter Segal', 1043624820.0),
#  ('Adam Shankman', 1026178614.0),
#  ('Byron Howard', 1023784195.0),
#  ('Jordan Peele', 1020144858.0),
#  ('Jonathan Liebesman', 1006933512.0),
#  ('Andy Fickman', 1001020386.0),
#  ('Gavin Hood', 997200110.0),
#  ('Edgar Wright', 962096799.0),
#  ('James DeMonaco', 959534616.0),
#  ('Danny Boyle', 932005282.0),
#  ('Rob Cohen', 907108988.0),
#  ('Harald Zwart', 906497936.0),
#  ('Michael Dougherty', 895377062.0),
#  ('Mike Thurmeier', 877244782.0),
#  ('Judd Apatow', 870940683.0),
#  ('Christopher Miller', 862860160.0),
#  ('Taika Waititi', 853977126.0),
#  ('John Lee Hancock', 843505778.0),
#  ('Nancy Meyers', 827336654.0),
#  ('Chad Stahelski', 824320202.0),
#  ('Patty Jenkins', 821847012.0),
#  ('Tarsem Singh', 819845078.0),
#  ('George Clooney', 816829764.0),
#  ('David Soren', 815720264.0),
#  ('Rob Minkoff', 801638108.0),
#  ('Joachim Rønning', 794191988.0),
#  ('Rob Letterman', 791091024.0),
#  ('Tim Miller', 783100000.0),
#  ('John Moore', 780142174.0),
#  ('Ben Affleck', 772700528.0),
#  ('Patrick Hughes', 765518490.0),
#  ('Robert Stromberg', 758539785.0),
#  ('Eric Darnell', 746921274.0),
#  ('Ruben Fleischer', 744419649.0),
#  ('Dan Scanlon', 743559607.0),
#  ('Phillip Noyce', 720619058.0),
#  ('Alfonso Cuarón', 716392705.0),
#  ('Chris Weitz', 709827462.0),
#  ('Tony Gilroy', 709439180.0),
#  ('Luc Besson', 704842106.0),
#  ('Christopher Landon', 702983250.0),
#  ('Mark Waters', 700402842.0),
#  ('David Slade', 698491347.0),
#  ('Ariel Schulman', 697043620.0),
#  ('Ron Clements', 695331111.0),
#  ('Gary Ross', 691210692.0),
#  ('Gore Verbinski', 670029026.0),
#  ('Jennifer Yuh Nelson', 665692281.0),
#  ('Don Hall', 657818612.0),
#  ('Alan Taylor', 644571402.0),
#  ('Adam Robitel', 638141896.0),
#  ('Tony Scott', 635943184.0),
#  ('Thor Freudenthal', 633701026.0),
#  ('Garth Jennings', 632443719.0),
#  ('Mark Osborne', 631744560.0),
#  ('Scott Moore', 628993004.0),
#  ('Eric Brevig', 606572402.0),
#  ('Nathan Greno', 591794936.0),
#  ('Timur Bekmambetov', 591579964.0),
#  ('Frank Coraci', 586694738.0),
#  ('Chris Sanders', 585178928.0),
#  ('Dave Green', 581847696.0),
#  ('Theodore Melfi', 571072050.0),
#  ('Sam Taylor-Johnson', 571006128.0),
#  ('Scott Waugh', 569100804.0),
#  ('Jordan Vogt-Roberts', 566652812.0),
#  ('Louis Leterrier', 562821936.0),
#  ('Robert Zemeckis', 562584796.0),
#  ('John Lasseter', 559852396.0),
#  ('Lana Wachowski', 555866978.0),
#  ('Chris Miller', 554987477.0),
#  ('Neil Burger', 546405180.0),
#  ('Brenda Chapman', 538983207.0),
#  ('Phil Johnston', 529221154.0),
#  ('Scott Cooper', 528187656.0),
#  ('Steve McQueen', 521732176.0),
#  ('Alessandro Carloni', 521170825.0),
#  ('Josh Cooley', 519802847.0),
#  ('Joe Carnahan', 509034254.0),
#  ('Woody Allen', 500650868.0),
#  ('Charles Martin Smith', 496418361.0),
#  ('Andy Tennant', 494462082.0),
#  ('Wes Anderson', 485726968.0),
#  ('Rich Moore', 471222889.0),
#  ('Alexander Payne', 464494150.0),
#  ('Jonathan M. Goldstein', 443770402.0),
#  ('Betty Thomas', 443140005.0),
#  ('Jason Moore', 440722958.0),
#  ('Craig Gillespie', 433038042.0),
#  ('Michael Gracey', 432844677.0),
#  ('Edward Zwick', 426602590.0),
#  ('Ken Kwapis', 426501056.0),
#  ('Andrew Adamson', 419665568.0),
#  ('John Hamburg', 419342518.0),
#  ('Michael Apted', 415686217.0),
#  ('James Mangold', 415440673.0),
#  ('Tom Hooper', 414211549.0),
#  ('Kevin Greutert', 408768126.0),
#  ('Galen T. Chu', 408579038.0),
#  ('Alex Kendrick', 407305965.0),
#  ('Breck Eisner', 403786100.0),
#  ('Luke Greenfield', 403424184.0),
#  ('David Frankel', 403394144.0),
#  ('Alex Proyas', 401361728.0),
#  ('Ava DuVernay', 398927544.0),
#  ('Rupert Sanders', 396600000.0),
#  ('Gary Winick', 393623998.0),
#  ('Baltasar Kormákur', 390080822.0),
#  ('John Erick Dowdle', 386572398.0),
#  ('Brian Fee', 383925276.0),
#  ('Jay Roach', 382591206.0),
#  ('Simon J. Smith', 373552094.0),
#  ('Joe Johnston', 370569774.0),
#  ('Burr Steers', 368916360.0),
#  ('Corin Hardy', 365550119.0),
#  ('Ben Falcone', 358323378.0),
#  ('Ivan Reitman', 353223170.0),
#  ('Clay Kaytis', 349779543.0),
#  ('Walt Dohrn', 346864462.0),
#  ('John Krasinski', 340677200.0),
#  ('Kirk Jones', 337246502.0),
#  ('Stephen Daldry', 336534342.0),
#  ('Mike Newell', 335154643.0),
#  ('Peter Sohn', 331926147.0),
#  ('Aaron Seltzer', 330389394.0),
#  ('Robert Schwentke', 325756584.0),
#  ('Randall Wallace', 323168666.0),
#  ('David Dobkin', 318339650.0),
#  ('Simon West', 312573423.0),
#  ('Paul Tibbitt', 311594032.0),
#  ('Jeff Wadlow', 311082962.0),
#  ('Paul Weitz', 310650585.0),
#  ('Chris Williams', 309979994.0),
#  ('Peter Ramsey', 306941670.0),
#  ('Stephen Sommers', 302469017.0),
#  ('Stephen Frears', 298065650.0),
#  ('Hoyt Yeatman', 292817841.0),
#  ('Cameron Crowe', 292663722.0),
#  ('Elizabeth Banks', 287506194.0),
#  ('Joseph Kosinski', 286168572.0),
#  ('Florian Henckel von Donnersmarck', 278731369.0),
#  ('Roar Uthaug', 274650803.0),
#  ('Sylvester Stallone', 274470394.0),
#  ('David Gordon Green', 273134062.0),
#  ('Ari Sandel', 272064492.0),
#  ('John Musker', 270997378.0),
#  ('Chris Wedge', 268426634.0),
#  ('John Madden', 263229268.0),
#  ('John R. Leonetti', 257047661.0),
#  ('Peter Spierig', 256089408.0),
#  ('Kenny Ortega', 252909177.0),
#  ('Mike Flanagan', 251471984.0),
#  ('Kris Pearn', 248384621.0),
#  ('Steve Martino', 246233113.0),
#  ('Simon Kinberg', 245000000.0),
#  ('Chris Columbus', 243637091.0),
#  ('Ari Aster', 240841714.0),
#  ('Justin Kurzel', 240697856.0),
#  ('Hayden Schlossberg', 234989584.0),
#  ('Morten Tyldum', 233555708.0),
#  ('Michel Gondry', 227817248.0),
#  ('Dean Devlin', 221600160.0),
#  ('Klay Hall', 219788712.0),
#  ('Gary Shore', 217124280.0),
#  ('Tony Leondis', 216909830.0),
#  ('Michael Mann', 214104620.0),
#  ('Sharon Maguire', 211952420.0),
#  ('Daniel Espinosa', 208076205.0),
#  ('Tyler Perry', 207959924.0),
#  ('Thea Sharrock', 207945075.0),
#  ('Babak Najafi', 205754447.0),
#  ('Ryan Murphy', 204594016.0),
#  ('Kelly Asbury', 197183546.0),
#  ('Michael Sucsy', 196114570.0),
#  ('Kevin Smith', 195377830.0),
#  ('Oren Peli', 193355800.0),
#  ('David R. Ellis', 186167139.0),
#  ('Trish Sie', 184724494.0),
#  ('George Tillman, Jr.', 184353632.0),
#  ('Tim Hill', 183953723.0),
#  ('Steve Carr', 183293131.0),
#  ('Larry Charles', 179379533.0),
#  ('Tod Williams', 177512032.0),
#  ('Mel Gibson', 175302354.0),
#  ('Andrew Niccol', 173930596.0),
#  ('Peter Billingsley', 171844840.0),
#  ('Tom Vaughan', 170000000.0),
#  ('Gabriele Muccino', 168167691.0),
#  ('Josh Trank', 167977596.0),
#  ('Ol Parker', 167225525.0),
#  ('Cedric Nicolas-Troyan', 164602163.0),
#  ('Jason Reitman', 163670000.0),
#  ('Angelina Jolie', 163442937.0),
#  ('Alex Garland', 159880658.0),
#  ('Fede Alvarez', 159047649.0),
#  ('Martin McDonagh', 158526998.0),
#  ('Steven Quale', 157887643.0),
#  ('Michael Engler', 157829576.0),
#  ('Allen Hughes', 157107755.0),
#  ("Gavin O'Connor", 155160045.0),
#  ('Brett Ratner', 152930623.0),
#  ('Jeff Tremaine', 151831537.0),
#  ('Roberts Gannaway', 151165787.0),
#  ('Pete Travis', 151161491.0),
#  ('Carl Rinsch', 150962475.0),
#  ('D.J. Caruso', 144492830.0),
#  ('Glenn Ficarra', 142851197.0),
#  ('Conrad Vernon', 140705322.0),
#  ('Scott Speer', 140470746.0),
#  ('Garth Davis', 140312928.0),
#  ('Steven Caple Jr.', 137944327.0),
#  ('Gerard McMurray', 137056262.0),
#  ('Oliver Stone', 134748021.0),
#  ('Michel Hazanavicius', 133432856.0),
#  ('Kathryn Bigelow', 132820716.0),
#  ('Thurop Van Orman', 131359052.0),
#  ('Nora Ephron', 129540499.0),
#  ('George Nolfi', 127869379.0),
#  ('James Watkins', 127730736.0),
#  ('Barry Cook', 126546518.0),
#  ('Nimród Antal', 126248813.0),
#  ('Henry Selick', 124596398.0),
#  ('Tate Taylor', 124272124.0),
#  ('James Marsh', 123726688.0),
#  ('Peter Lepeniotis', 122529966.0),
#  ('Gregory Jacobs', 122513057.0),
#  ('Jonathan Mostow', 122444772.0),
#  ('James Gray', 120964704.0),
#  ('Dylan Brown', 119559110.0),
#  ('Will Speck', 114501299.0),
#  ('David Hackl', 113857533.0),
#  ('Nikolaj Arcel', 113231078.0),
#  ('Michael Lembeck', 112462508.0),
#  ('Christian Ditter', 112343513.0),
#  ('Etan Cohen', 111811453.0),
#  ('Jill Culton', 111615070.0),
#  ('Bennett Miller', 110206216.0),
#  ('Jimmy Hayward', 110000000.0),
#  ('J Blakeson', 109906372.0),
#  ('P.J. Hogan', 108332743.0),
#  ('Dan Trachtenberg', 108286421.0),
#  ('Graham Annable', 108255770.0),
#  ('Chris Butler', 107139399.0),
#  ('Jorge Blanco', 104945765.0),
#  ('Stiles White', 103590271.0),
#  ('William Brent Bell', 101758490.0),
#  ('Miguel Arteta', 100654149.0),
#  ('Spike Jonze', 100086793.0),
#  ('Mark Levin', 100076342.0),
#  ('Nima Nourizadeh', 100000000.0),
#  ('Scott Hicks', 99357138.0),
#  ('David Twohy', 98337295.0),
#  ('Greg Mottola', 97552050.0),
#  ('Wes Craven', 97138686.0),
#  ('Mikael Håfström', 96047633.0),
#  ('Nick Cassavetes', 95714875.0),
#  ('Brian Helgeland', 95020213.0),
#  ('Dan Mazer', 94073028.0),
#  ('Kay Cannon', 93674786.0),
#  ('Jodie Foster', 93282604.0),
#  ('Stuart Hazeldine', 92924405.0),
#  ('David Wain', 92380927.0),
#  ('Walt Becker', 92219310.0),
#  ('Patrick Tatopoulos', 91353501.0),
#  ('Sam Raimi', 90810892.0),
#  ('Steve Antin', 89519773.0),
#  ('Tom McCarthy', 88346473.0),
#  ('Kevin Macdonald', 87784194.0),
#  ('John Stevenson', 87625666.0),
#  ('Sam Fell', 86900000.0),
#  ('Jake Schreier', 85512300.0),
#  ('Ole Bornedal', 85446075.0),
#  ('Brad Furman', 85412898.0),
#  ('Marc Lawrence', 85280250.0),
#  ('Henry Joost', 85241496.0),
#  ('Paul Weiland', 84601681.0),
#  ('Tom Dey', 83761844.0),
#  ('John Whitesell', 83615414.0),
#  ('F. Javier Gutiérrez', 83080890.0),
#  ('Bryan Bertino', 82391145.0),
#  ('Yorgos Lanthimos', 82124805.0),
#  ('Aleksander Bach', 81967450.0),
#  ('Christian Gudegast', 80509622.0),
#  ('Jeremy Garelick', 79799880.0),
#  ('R.J. Cutler', 78874843.0),
#  ('Bill Holderman', 78720293.0),
#  ('Peter Cornwell', 77527732.0),
#  ('Alan Poul', 77477008.0),
#  ('Jake Szymanski', 77068246.0),
#  ('Greta Gerwig', 76858273.0),
#  ('Stefano Sollima', 75836683.0),
#  ('Jeff Tomsic', 75100000.0),
#  ('Kenneth Lonergan', 75026965.0),
#  ('John Wells', 74188937.0),
#  ('Patricia Riggen', 73983359.0),
#  ('Steve Shill', 73830340.0),
#  ('Jon Avnet', 73174566.0),
#  ('Gene Stupnitsky', 72457330.0),
#  ('Alexandre Aja', 72436439.0),
#  ('Drew Goddard', 70742948.0),
#  ('Fred Wolf', 70442940.0),
#  ('John Luessenhop', 69055695.0),
#  ('Grant Heslov', 68729358.0),
#  ('Brad Silberling', 68688831.0),
#  ('Brad Anderson', 68572378.0),
#  ('Dave Filoni', 68282844.0),
#  ('Akiva Schaffer', 68267862.0),
#  ('Adrian Grunberg', 68041378.0),
#  ('Christopher Spencer', 67800064.0),
#  ('Daniel Stamm', 67738090.0),
#  ('Nicolai Fuglsig', 67131266.0),
#  ('Aneesh Chaganty', 66265218.0),
#  ('Michael Cuesta', 66167951.0),
#  ('Lee Toland Krieger', 65663276.0),
#  ('Anton Corbijn', 65464324.0),
#  ('Callan Brunker', 65146020.0),
#  ('Roger Donaldson', 64822796.0),
#  ('Kirk DeMicco', 64762724.0),
#  ('Steve Pink', 64572262.0),
#  ('Denzel Washington', 64414761.0),
#  ('David Gelb', 64110728.0),
#  ('Michael McCullers', 63833449.0),
#  ('Levan Gabriadze', 62882090.0),
#  ('Hany Abu-Assad', 62832209.0),
#  ('Harold Ramis', 62357900.0),
#  ('John Crowley', 62076141.0),
#  ('Simon Curtis', 61619773.0),
#  ('Greg Berlanti', 60848932.0),
#  ('James McTeigue', 60462347.0),
#  ('David M. Rosenthal', 60273173.0),
#  ('Michael Tiddes', 60141683.0),
#  ('Aaron Sorkin', 59284015.0),
#  ('Hans Petter Moland', 59213931.0),
#  ('Roger Michell', 58785180.0),
#  ('Xavier Palud', 56309766.0),
#  ('Michael Showalter', 56303596.0),
#  ('Jean-Marc Vallée', 55198285.0),
#  ('Gus Van Sant', 54586584.0),
#  ('John Hillcoat', 53676580.0),
#  ('Scott Frank', 53181600.0),
#  ('Ciarán Foy', 52882018.0),
#  ('Gregory Hoblit', 52659594.0),
#  ('Christian E. Christiansen', 52545707.0),
#  ('Marc Silverstein', 51748264.0),
#  ('Ken Scott', 51164106.0),
#  ('John Patrick Shanley', 50907234.0),
#  ('Anthony Hemingway', 50365377.0),
#  ('Dan Gilroy', 50300000.0),
#  ('Josh Gordon', 49830607.0),
#  ('Jim Field Smith', 49779728.0),
#  ('Baz Luhrmann', 49554002.0),
#  ('Doug Ellin', 49263404.0),
#  ('Pierre Morel', 48818723.0),
#  ('Spike Lee', 48686605.0),
#  ('James L. Brooks', 48668907.0),
#  ('Shane Acker', 48428063.0),
#  ('Paul Thomas Anderson', 47756590.0),
#  ('Olatunde Osunsanmi', 47709193.0),
#  ('Sean McNamara', 47088990.0),
#  ('Kevin Reynolds', 46069568.0),
#  ('Paul McGuigan', 45465299.0),
#  ('Lucia Aniello', 45056771.0),
#  ('Taylor Sheridan', 44998252.0),
#  ('Benny Boom', 44922302.0),
#  ('Sanaa Hamri', 44352417.0),
#  ('Richard Linklater', 44349000.0),
#  ('Johannes Roberts', 44235023.0),
#  ('Jim Sheridan', 43318349.0),
#  ('Mark Steven Johnson', 43042835.0),
#  ('Ric Roman Waugh', 42930462.0),
#  ('Chris Lofing', 42664410.0),
#  ('Jessie Nelson', 42426912.0),
#  ('Marco Schnabel', 41819064.0),
#  ('Julius Avery', 41657844.0),
#  ('Jonathan Demme', 41325328.0),
#  ('Richie Keen', 41087017.0),
#  ('Robert Eggers', 40423945.0),
#  ('Phil Traill', 40105542.0),
#  ('Stephen Merchant', 39055536.0),
#  ('Gina Prince-Bythewood', 38105395.0),
#  ('Salim Akil', 37710610.0),
#  ('Jason Zada', 37608299.0),
#  ('David Mackenzie', 37589296.0),
#  ('Tom Hanks', 36160375.0),
#  ('Michael Hoffman', 35926213.0),
#  ('Albert Hughes', 35808437.0),
#  ('Stella Meghie', 34000284.0),
#  ('Susanna Fogel', 33562069.0),
#  ('Peter Sollett', 32973937.0),
#  ('Dean Israelite', 32248241.0),
#  ('David Yarovesky', 32139941.0),
#  ('Jon Cassar', 30658387.0),
#  ('Thomas Carter', 30127963.0),
#  ('Harold Cronk', 29789000.0),
#  ('Neil LaBute', 27640028.0),
#  ('Hallie Meyers-Shyer', 27020284.0),
#  ('Stacy Title', 26667197.0),
#  ('Tom Gormican', 26049082.0),
#  ('Yann Demange', 26000000.0),
#  ('Leslie Small', 23600000.0),
#  ('Michael Dowse', 22799033.0),
#  ('Olivia Wilde', 22220378.0),
#  ('Jay Chandrasekhar', 18850674.0),
#  ('Charles Stone III', 17665000.0),
#  ('Tina Gordon Chism', 17399000.0),
#  ('Nicholas McCarthy', 14856291.0),
#  ('Sylvain White', 11817275.0),
#  ('Damien Dante Wayans', 32.0)]

# %%
director_ranking = {}
i = 1
for info in sorted_directors:
    if director_ranking.get(info[0]) == None:
        director_ranking[info[0]] = i
    else:
        director_ranking[info[0]] += 1
    i = i+1

# %%
director_ranking
# Out:
# {'Steven Spielberg': 1,
#  'Christopher Nolan': 2,
#  'Michael Bay': 3,
#  'Clint Eastwood': 4,
#  'Zack Snyder': 5,
#  'Ridley Scott': 6,
#  'James Wan': 7,
#  'Bryan Singer': 8,
#  'J.J. Abrams': 9,
#  'Francis Lawrence': 10,
#  'Peter Jackson': 11,
#  'Joe Russo': 12,
#  'Carlos Saldanha': 13,
#  'Todd Phillips': 14,
#  'Brad Bird': 15,
#  'Shawn Levy': 16,
#  'Peter Berg': 17,
#  'Marc Webb': 18,
#  'David Yates': 19,
#  'Jon Favreau': 20,
#  'Ron Howard': 21,
#  'M. Night Shyamalan': 22,
#  'Justin Lin': 23,
#  'Christopher McQuarrie': 24,
#  'Dean DeBlois': 25,
#  'Nicholas Stoller': 26,
#  'Rob Marshall': 27,
#  'Chris Renaud': 28,
#  'F. Gary Gray': 29,
#  'David Leitch': 30,
#  'Tom McGrath': 31,
#  'Jaume Collet-Serra': 32,
#  'Jon M. Chu': 33,
#  'Matt Reeves': 34,
#  'Peyton Reed': 35,
#  'Roland Emmerich': 36,
#  'Jon Watts': 37,
#  'Pierre Coffin': 38,
#  'Sam Mendes': 39,
#  'Jake Kasdan': 40,
#  'Anthony Russo': 41,
#  'Lee Unkrich': 42,
#  'Dennis Dugan': 43,
#  'Adam McKay': 44,
#  'Guillermo del Toro': 45,
#  'James Gunn': 46,
#  'Pete Docter': 47,
#  'Raja Gosnell': 48,
#  'Ryan Coogler': 49,
#  'Sean Anders': 50,
#  'Guy Ritchie': 51,
#  'Paul Feig': 52,
#  'Seth Gordon': 53,
#  'Wes Ball': 54,
#  'Brad Peyton': 55,
#  'Genndy Tartakovsky': 56,
#  'James Cameron': 57,
#  'David Fincher': 58,
#  'Lasse Hallström': 59,
#  'Rian Johnson': 60,
#  'David O. Russell': 61,
#  'Quentin Tarantino': 62,
#  'Denis Villeneuve': 63,
#  'Andrew Stanton': 64,
#  'Martin Scorsese': 65,
#  'Matthew Vaughn': 66,
#  'Seth MacFarlane': 67,
#  'Shane Black': 68,
#  'Peter Farrelly': 69,
#  'David F. Sandberg': 70,
#  'Rawson Marshall Thurber': 71,
#  'Anne Fletcher': 72,
#  'Marc Forster': 73,
#  'Mike Mitchell': 74,
#  'Antoine Fuqua': 75,
#  'Doug Liman': 76,
#  'Jon Turteltaub': 77,
#  'Malcolm D. Lee': 78,
#  'Paul W.S. Anderson': 79,
#  'Paul Greengrass': 80,
#  'Neill Blomkamp': 81,
#  'Tim Story': 82,
#  'McG': 83,
#  'Tim Burton': 84,
#  'Will Gluck': 85,
#  'Andy Muschietti': 86,
#  'Colin Trevorrow': 87,
#  'Olivier Megaton': 88,
#  'James Bobin': 89,
#  'David Ayer': 90,
#  'Rupert Wyatt': 91,
#  'Robert Rodriguez': 92,
#  'Jonathan Levine': 93,
#  'Steven Soderbergh': 94,
#  'Scott Derrickson': 95,
#  'James Foley': 96,
#  'Catherine Hardwicke': 97,
#  'Joe Wright': 98,
#  'Phyllida Lloyd': 99,
#  'Ethan Coen': 100,
#  'Michael Patrick King': 101,
#  'Joss Whedon': 102,
#  'Darren Aronofsky': 103,
#  'Ang Lee': 104,
#  'Martin Campbell': 105,
#  'J. A. Bayona': 106,
#  'Ben Stiller': 107,
#  'Jennifer Lee': 108,
#  'Alejandro González Iñárritu': 109,
#  'Garry Marshall': 110,
#  'Kenneth Branagh': 111,
#  'Duncan Jones': 112,
#  'Kyle Balda': 113,
#  'Robert Luketic': 114,
#  'Damien Chazelle': 115,
#  'Travis Knight': 116,
#  'George Miller': 117,
#  'Gareth Edwards': 118,
#  'Peter Segal': 119,
#  'Adam Shankman': 120,
#  'Byron Howard': 121,
#  'Jordan Peele': 122,
#  'Jonathan Liebesman': 123,
#  'Andy Fickman': 124,
#  'Gavin Hood': 125,
#  'Edgar Wright': 126,
#  'James DeMonaco': 127,
#  'Danny Boyle': 128,
#  'Rob Cohen': 129,
#  'Harald Zwart': 130,
#  'Michael Dougherty': 131,
#  'Mike Thurmeier': 132,
#  'Judd Apatow': 133,
#  'Christopher Miller': 134,
#  'Taika Waititi': 135,
#  'John Lee Hancock': 136,
#  'Nancy Meyers': 137,
#  'Chad Stahelski': 138,
#  'Patty Jenkins': 139,
#  'Tarsem Singh': 140,
#  'George Clooney': 141,
#  'David Soren': 142,
#  'Rob Minkoff': 143,
#  'Joachim Rønning': 144,
#  'Rob Letterman': 145,
#  'Tim Miller': 146,
#  'John Moore': 147,
#  'Ben Affleck': 148,
#  'Patrick Hughes': 149,
#  'Robert Stromberg': 150,
#  'Eric Darnell': 151,
#  'Ruben Fleischer': 152,
#  'Dan Scanlon': 153,
#  'Phillip Noyce': 154,
#  'Alfonso Cuarón': 155,
#  'Chris Weitz': 156,
#  'Tony Gilroy': 157,
#  'Luc Besson': 158,
#  'Christopher Landon': 159,
#  'Mark Waters': 160,
#  'David Slade': 161,
#  'Ariel Schulman': 162,
#  'Ron Clements': 163,
#  'Gary Ross': 164,
#  'Gore Verbinski': 165,
#  'Jennifer Yuh Nelson': 166,
#  'Don Hall': 167,
#  'Alan Taylor': 168,
#  'Adam Robitel': 169,
#  'Tony Scott': 170,
#  'Thor Freudenthal': 171,
#  'Garth Jennings': 172,
#  'Mark Osborne': 173,
#  'Scott Moore': 174,
#  'Eric Brevig': 175,
#  'Nathan Greno': 176,
#  'Timur Bekmambetov': 177,
#  'Frank Coraci': 178,
#  'Chris Sanders': 179,
#  'Dave Green': 180,
#  'Theodore Melfi': 181,
#  'Sam Taylor-Johnson': 182,
#  'Scott Waugh': 183,
#  'Jordan Vogt-Roberts': 184,
#  'Louis Leterrier': 185,
#  'Robert Zemeckis': 186,
#  'John Lasseter': 187,
#  'Lana Wachowski': 188,
#  'Chris Miller': 189,
#  'Neil Burger': 190,
#  'Brenda Chapman': 191,
#  'Phil Johnston': 192,
#  'Scott Cooper': 193,
#  'Steve McQueen': 194,
#  'Alessandro Carloni': 195,
#  'Josh Cooley': 196,
#  'Joe Carnahan': 197,
#  'Woody Allen': 198,
#  'Charles Martin Smith': 199,
#  'Andy Tennant': 200,
#  'Wes Anderson': 201,
#  'Rich Moore': 202,
#  'Alexander Payne': 203,
#  'Jonathan M. Goldstein': 204,
#  'Betty Thomas': 205,
#  'Jason Moore': 206,
#  'Craig Gillespie': 207,
#  'Michael Gracey': 208,
#  'Edward Zwick': 209,
#  'Ken Kwapis': 210,
#  'Andrew Adamson': 211,
#  'John Hamburg': 212,
#  'Michael Apted': 213,
#  'James Mangold': 214,
#  'Tom Hooper': 215,
#  'Kevin Greutert': 216,
#  'Galen T. Chu': 217,
#  'Alex Kendrick': 218,
#  'Breck Eisner': 219,
#  'Luke Greenfield': 220,
#  'David Frankel': 221,
#  'Alex Proyas': 222,
#  'Ava DuVernay': 223,
#  'Rupert Sanders': 224,
#  'Gary Winick': 225,
#  'Baltasar Kormákur': 226,
#  'John Erick Dowdle': 227,
#  'Brian Fee': 228,
#  'Jay Roach': 229,
#  'Simon J. Smith': 230,
#  'Joe Johnston': 231,
#  'Burr Steers': 232,
#  'Corin Hardy': 233,
#  'Ben Falcone': 234,
#  'Ivan Reitman': 235,
#  'Clay Kaytis': 236,
#  'Walt Dohrn': 237,
#  'John Krasinski': 238,
#  'Kirk Jones': 239,
#  'Stephen Daldry': 240,
#  'Mike Newell': 241,
#  'Peter Sohn': 242,
#  'Aaron Seltzer': 243,
#  'Robert Schwentke': 244,
#  'Randall Wallace': 245,
#  'David Dobkin': 246,
#  'Simon West': 247,
#  'Paul Tibbitt': 248,
#  'Jeff Wadlow': 249,
#  'Paul Weitz': 250,
#  'Chris Williams': 251,
#  'Peter Ramsey': 252,
#  'Stephen Sommers': 253,
#  'Stephen Frears': 254,
#  'Hoyt Yeatman': 255,
#  'Cameron Crowe': 256,
#  'Elizabeth Banks': 257,
#  'Joseph Kosinski': 258,
#  'Florian Henckel von Donnersmarck': 259,
#  'Roar Uthaug': 260,
#  'Sylvester Stallone': 261,
#  'David Gordon Green': 262,
#  'Ari Sandel': 263,
#  'John Musker': 264,
#  'Chris Wedge': 265,
#  'John Madden': 266,
#  'John R. Leonetti': 267,
#  'Peter Spierig': 268,
#  'Kenny Ortega': 269,
#  'Mike Flanagan': 270,
#  'Kris Pearn': 271,
#  'Steve Martino': 272,
#  'Simon Kinberg': 273,
#  'Chris Columbus': 274,
#  'Ari Aster': 275,
#  'Justin Kurzel': 276,
#  'Hayden Schlossberg': 277,
#  'Morten Tyldum': 278,
#  'Michel Gondry': 279,
#  'Dean Devlin': 280,
#  'Klay Hall': 281,
#  'Gary Shore': 282,
#  'Tony Leondis': 283,
#  'Michael Mann': 284,
#  'Sharon Maguire': 285,
#  'Daniel Espinosa': 286,
#  'Tyler Perry': 287,
#  'Thea Sharrock': 288,
#  'Babak Najafi': 289,
#  'Ryan Murphy': 290,
#  'Kelly Asbury': 291,
#  'Michael Sucsy': 292,
#  'Kevin Smith': 293,
#  'Oren Peli': 294,
#  'David R. Ellis': 295,
#  'Trish Sie': 296,
#  'George Tillman, Jr.': 297,
#  'Tim Hill': 298,
#  'Steve Carr': 299,
#  'Larry Charles': 300,
#  'Tod Williams': 301,
#  'Mel Gibson': 302,
#  'Andrew Niccol': 303,
#  'Peter Billingsley': 304,
#  'Tom Vaughan': 305,
#  'Gabriele Muccino': 306,
#  'Josh Trank': 307,
#  'Ol Parker': 308,
#  'Cedric Nicolas-Troyan': 309,
#  'Jason Reitman': 310,
#  'Angelina Jolie': 311,
#  'Alex Garland': 312,
#  'Fede Alvarez': 313,
#  'Martin McDonagh': 314,
#  'Steven Quale': 315,
#  'Michael Engler': 316,
#  'Allen Hughes': 317,
#  "Gavin O'Connor": 318,
#  'Brett Ratner': 319,
#  'Jeff Tremaine': 320,
#  'Roberts Gannaway': 321,
#  'Pete Travis': 322,
#  'Carl Rinsch': 323,
#  'D.J. Caruso': 324,
#  'Glenn Ficarra': 325,
#  'Conrad Vernon': 326,
#  'Scott Speer': 327,
#  'Garth Davis': 328,
#  'Steven Caple Jr.': 329,
#  'Gerard McMurray': 330,
#  'Oliver Stone': 331,
#  'Michel Hazanavicius': 332,
#  'Kathryn Bigelow': 333,
#  'Thurop Van Orman': 334,
#  'Nora Ephron': 335,
#  'George Nolfi': 336,
#  'James Watkins': 337,
#  'Barry Cook': 338,
#  'Nimród Antal': 339,
#  'Henry Selick': 340,
#  'Tate Taylor': 341,
#  'James Marsh': 342,
#  'Peter Lepeniotis': 343,
#  'Gregory Jacobs': 344,
#  'Jonathan Mostow': 345,
#  'James Gray': 346,
#  'Dylan Brown': 347,
#  'Will Speck': 348,
#  'David Hackl': 349,
#  'Nikolaj Arcel': 350,
#  'Michael Lembeck': 351,
#  'Christian Ditter': 352,
#  'Etan Cohen': 353,
#  'Jill Culton': 354,
#  'Bennett Miller': 355,
#  'Jimmy Hayward': 356,
#  'J Blakeson': 357,
#  'P.J. Hogan': 358,
#  'Dan Trachtenberg': 359,
#  'Graham Annable': 360,
#  'Chris Butler': 361,
#  'Jorge Blanco': 362,
#  'Stiles White': 363,
#  'William Brent Bell': 364,
#  'Miguel Arteta': 365,
#  'Spike Jonze': 366,
#  'Mark Levin': 367,
#  'Nima Nourizadeh': 368,
#  'Scott Hicks': 369,
#  'David Twohy': 370,
#  'Greg Mottola': 371,
#  'Wes Craven': 372,
#  'Mikael Håfström': 373,
#  'Nick Cassavetes': 374,
#  'Brian Helgeland': 375,
#  'Dan Mazer': 376,
#  'Kay Cannon': 377,
#  'Jodie Foster': 378,
#  'Stuart Hazeldine': 379,
#  'David Wain': 380,
#  'Walt Becker': 381,
#  'Patrick Tatopoulos': 382,
#  'Sam Raimi': 383,
#  'Steve Antin': 384,
#  'Tom McCarthy': 385,
#  'Kevin Macdonald': 386,
#  'John Stevenson': 387,
#  'Sam Fell': 388,
#  'Jake Schreier': 389,
#  'Ole Bornedal': 390,
#  'Brad Furman': 391,
#  'Marc Lawrence': 392,
#  'Henry Joost': 393,
#  'Paul Weiland': 394,
#  'Tom Dey': 395,
#  'John Whitesell': 396,
#  'F. Javier Gutiérrez': 397,
#  'Bryan Bertino': 398,
#  'Yorgos Lanthimos': 399,
#  'Aleksander Bach': 400,
#  'Christian Gudegast': 401,
#  'Jeremy Garelick': 402,
#  'R.J. Cutler': 403,
#  'Bill Holderman': 404,
#  'Peter Cornwell': 405,
#  'Alan Poul': 406,
#  'Jake Szymanski': 407,
#  'Greta Gerwig': 408,
#  'Stefano Sollima': 409,
#  'Jeff Tomsic': 410,
#  'Kenneth Lonergan': 411,
#  'John Wells': 412,
#  'Patricia Riggen': 413,
#  'Steve Shill': 414,
#  'Jon Avnet': 415,
#  'Gene Stupnitsky': 416,
#  'Alexandre Aja': 417,
#  'Drew Goddard': 418,
#  'Fred Wolf': 419,
#  'John Luessenhop': 420,
#  'Grant Heslov': 421,
#  'Brad Silberling': 422,
#  'Brad Anderson': 423,
#  'Dave Filoni': 424,
#  'Akiva Schaffer': 425,
#  'Adrian Grunberg': 426,
#  'Christopher Spencer': 427,
#  'Daniel Stamm': 428,
#  'Nicolai Fuglsig': 429,
#  'Aneesh Chaganty': 430,
#  'Michael Cuesta': 431,
#  'Lee Toland Krieger': 432,
#  'Anton Corbijn': 433,
#  'Callan Brunker': 434,
#  'Roger Donaldson': 435,
#  'Kirk DeMicco': 436,
#  'Steve Pink': 437,
#  'Denzel Washington': 438,
#  'David Gelb': 439,
#  'Michael McCullers': 440,
#  'Levan Gabriadze': 441,
#  'Hany Abu-Assad': 442,
#  'Harold Ramis': 443,
#  'John Crowley': 444,
#  'Simon Curtis': 445,
#  'Greg Berlanti': 446,
#  'James McTeigue': 447,
#  'David M. Rosenthal': 448,
#  'Michael Tiddes': 449,
#  'Aaron Sorkin': 450,
#  'Hans Petter Moland': 451,
#  'Roger Michell': 452,
#  'Xavier Palud': 453,
#  'Michael Showalter': 454,
#  'Jean-Marc Vallée': 455,
#  'Gus Van Sant': 456,
#  'John Hillcoat': 457,
#  'Scott Frank': 458,
#  'Ciarán Foy': 459,
#  'Gregory Hoblit': 460,
#  'Christian E. Christiansen': 461,
#  'Marc Silverstein': 462,
#  'Ken Scott': 463,
#  'John Patrick Shanley': 464,
#  'Anthony Hemingway': 465,
#  'Dan Gilroy': 466,
#  'Josh Gordon': 467,
#  'Jim Field Smith': 468,
#  'Baz Luhrmann': 469,
#  'Doug Ellin': 470,
#  'Pierre Morel': 471,
#  'Spike Lee': 472,
#  'James L. Brooks': 473,
#  'Shane Acker': 474,
#  'Paul Thomas Anderson': 475,
#  'Olatunde Osunsanmi': 476,
#  'Sean McNamara': 477,
#  'Kevin Reynolds': 478,
#  'Paul McGuigan': 479,
#  'Lucia Aniello': 480,
#  'Taylor Sheridan': 481,
#  'Benny Boom': 482,
#  'Sanaa Hamri': 483,
#  'Richard Linklater': 484,
#  'Johannes Roberts': 485,
#  'Jim Sheridan': 486,
#  'Mark Steven Johnson': 487,
#  'Ric Roman Waugh': 488,
#  'Chris Lofing': 489,
#  'Jessie Nelson': 490,
#  'Marco Schnabel': 491,
#  'Julius Avery': 492,
#  'Jonathan Demme': 493,
#  'Richie Keen': 494,
#  'Robert Eggers': 495,
#  'Phil Traill': 496,
#  'Stephen Merchant': 497,
#  'Gina Prince-Bythewood': 498,
#  'Salim Akil': 499,
#  'Jason Zada': 500,
#  'David Mackenzie': 501,
#  'Tom Hanks': 502,
#  'Michael Hoffman': 503,
#  'Albert Hughes': 504,
#  'Stella Meghie': 505,
#  'Susanna Fogel': 506,
#  'Peter Sollett': 507,
#  'Dean Israelite': 508,
#  'David Yarovesky': 509,
#  'Jon Cassar': 510,
#  'Thomas Carter': 511,
#  'Harold Cronk': 512,
#  'Neil LaBute': 513,
#  'Hallie Meyers-Shyer': 514,
#  'Stacy Title': 515,
#  'Tom Gormican': 516,
#  'Yann Demange': 517,
#  'Leslie Small': 518,
#  'Michael Dowse': 519,
#  'Olivia Wilde': 520,
#  'Jay Chandrasekhar': 521,
#  'Charles Stone III': 522,
#  'Tina Gordon Chism': 523,
#  'Nicholas McCarthy': 524,
#  'Sylvain White': 525,
#  'Damien Dante Wayans': 526}
